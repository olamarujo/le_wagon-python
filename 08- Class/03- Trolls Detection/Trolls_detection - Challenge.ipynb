# %% [markdown]
#  ![Emil](data:image/png;base64,...)

# %% [markdown]
# # Trolls detection

# %% [markdown]
# # Install Pycaret

# %% [markdown]
# We are going to be using the PyCaret libary later on in this challenge, please run the cell below to install it. It might take a minute or so (if you are asked to restart your runtime, please do so)
#
# Once done, run the second cell and you should see "pycaret==*someversion*".
#
# If that's the case you are good to go! If not, and the output is blank, then raise a ticket with a TA!

# %%
# Run first

#!pip install pycaret
# Out:
# Looking in indexes: https://pypi.org/simple, https://access_dc:****@gitlab.com/api/v4/projects/24584563/packages/pypi/simple, https://access_dc:****@gitlab.com/api/v4/projects/26485551/packages/pypi/simple
# Collecting pycaret
#   Downloading pycaret-3.3.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: ipython>=5.5.0 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pycaret) (8.5.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pycaret) (7.7.2)
# Requirement already satisfied: tqdm>=4.62.0 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pycaret) (4.64.1)
# Requirement already satisfied: numpy<1.27,>=1.21 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pycaret) (1.23.4)
# Requirement already satisfied: pandas<2.2.0 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pycaret) (1.4.4)
# Requirement already satisfied: jinja2>=3 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pycaret) (3.1.2)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pycaret) (1.8.1)
# Collecting joblib>=1.2.0 (from pycaret)
#   Using cached joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting scikit-learn>1.4.0 (from pycaret)
#   Downloading scikit_learn-1.4.1.post1-cp310-cp310-macosx_10_9_x86_64.whl.metadata (11 kB)
# Collecting pyod>=1.1.3 (from pycaret)
#   Downloading pyod-1.1.3.tar.gz (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.5/160.5 kB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting imbalanced-learn>=0.12.0 (from pycaret)
#   Downloading imbalanced_learn-0.12.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting category-encoders>=2.4.0 (from pycaret)
#   Downloading category_encoders-2.6.3-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting lightgbm>=3.0.0 (from pycaret)
#   Downloading lightgbm-4.3.0-py3-none-macosx_10_15_x86_64.macosx_11_6_x86_64.macosx_12_5_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: numba>=0.55.0 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pycaret) (0.58.1)
# Requirement already satisfied: requests>=2.27.1 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pycaret) (2.28.1)
# Requirement already satisfied: psutil>=5.9.0 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pycaret) (5.9.3)
# Requirement already satisfied: markupsafe>=2.0.1 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pycaret) (2.1.4)
# Requirement already satisfied: importlib-metadata>=4.12.0 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pycaret) (5.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pycaret) (5.7.0)
# Requirement already satisfied: cloudpickle in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pycaret) (2.2.0)
# Collecting deprecation>=2.1.0 (from pycaret)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting xxhash (from pycaret)
#   Downloading xxhash-3.4.1-cp310-cp310-macosx_10_9_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: matplotlib<3.8.0 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pycaret) (3.5.3)
# Collecting scikit-plot>=0.3.7 (from pycaret)
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Collecting yellowbrick>=1.4 (from pycaret)
#   Downloading yellowbrick-1.5-py3-none-any.whl (282 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.6/282.6 kB 3.0 MB/s eta 0:00:0000:0100:01
# Collecting plotly>=5.14.0 (from pycaret)
#   Downloading plotly-5.19.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting kaleido>=0.2.1 (from pycaret)
#   Downloading kaleido-0.2.1-py2.py3-none-macosx_10_11_x86_64.whl (85.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 MB 4.0 MB/s eta 0:00:0000:0100:01
# Collecting schemdraw==0.15 (from pycaret)
#   Downloading schemdraw-0.15-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 3.2 MB/s eta 0:00:00
# Collecting plotly-resampler>=0.8.3.1 (from pycaret)
#   Downloading plotly_resampler-0.9.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: statsmodels>=0.12.1 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pycaret) (0.14.1)
# Collecting sktime>=0.26.0 (from pycaret)
#   Downloading sktime-0.26.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: tbats>=1.1.3 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pycaret) (1.1.3)
# Collecting pmdarima>=2.0.4 (from pycaret)
#   Downloading pmdarima-2.0.4-cp310-cp310-macosx_10_9_x86_64.whl.metadata (7.8 kB)
# Collecting wurlitzer (from pycaret)
#   Downloading wurlitzer-3.0.3-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: patsy>=0.5.1 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from category-encoders>=2.4.0->pycaret) (0.5.6)
# Requirement already satisfied: packaging in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from deprecation>=2.1.0->pycaret) (21.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from imbalanced-learn>=0.12.0->pycaret) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from importlib-metadata>=4.12.0->pycaret) (3.10.0)
# Requirement already satisfied: backcall in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: decorator in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret) (3.0.31)
# Requirement already satisfied: pygments>=2.4.0 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret) (2.13.0)
# Requirement already satisfied: stack-data in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret) (0.5.1)
# Requirement already satisfied: traitlets>=5 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret) (5.5.0)
# Requirement already satisfied: pexpect>4.3 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret) (4.8.0)
# Requirement already satisfied: appnope in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret) (0.1.3)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipywidgets>=7.6.5->pycaret) (6.15.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipywidgets>=7.6.5->pycaret) (3.6.1)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipywidgets>=7.6.5->pycaret) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib<3.8.0->pycaret) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib<3.8.0->pycaret) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib<3.8.0->pycaret) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib<3.8.0->pycaret) (9.1.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib<3.8.0->pycaret) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib<3.8.0->pycaret) (2.8.2)
# Requirement already satisfied: fastjsonschema in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nbformat>=4.2.0->pycaret) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nbformat>=4.2.0->pycaret) (4.16.0)
# Requirement already satisfied: jupyter-core in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nbformat>=4.2.0->pycaret) (4.11.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from numba>=0.55.0->pycaret) (0.41.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pandas<2.2.0->pycaret) (2022.1)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from plotly>=5.14.0->pycaret) (8.1.0)
# Collecting dash>=2.9.0 (from plotly-resampler>=0.8.3.1->pycaret)
#   Downloading dash-2.15.0-py3-none-any.whl.metadata (11 kB)
# Collecting orjson<4.0.0,>=3.8.0 (from plotly-resampler>=0.8.3.1->pycaret)
#   Downloading orjson-3.9.14-cp310-cp310-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 3.6 MB/s eta 0:00:00
# Collecting tsdownsample==0.1.2 (from plotly-resampler>=0.8.3.1->pycaret)
#   Downloading tsdownsample-0.1.2-cp310-cp310-macosx_10_7_x86_64.whl.metadata (7.0 kB)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pmdarima>=2.0.4->pycaret) (0.29.32)
# Requirement already satisfied: urllib3 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pmdarima>=2.0.4->pycaret) (1.26.12)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pmdarima>=2.0.4->pycaret) (63.2.0)
# Requirement already satisfied: six in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pyod>=1.1.3->pycaret) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests>=2.27.1->pycaret) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests>=2.27.1->pycaret) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests>=2.27.1->pycaret) (2022.9.24)
# Collecting scikit-base<0.8.0 (from sktime>=0.26.0->pycaret)
#   Downloading scikit_base-0.7.2-py3-none-any.whl.metadata (8.7 kB)
# Collecting Flask<3.1,>=1.0.4 (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret)
#   Downloading flask-3.0.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: Werkzeug<3.1 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.1)
# Collecting dash-html-components==2.0.0 (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-core-components==2.0.0 (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-table==5.0.0 (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret)
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (4.4.0)
# Collecting retrying (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.5.6)
# Requirement already satisfied: debugpy>=1.0 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.6.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (7.4.3)
# Requirement already satisfied: pyzmq>=17 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.18.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pexpect>4.3->ipython>=5.5.0->pycaret) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (6.4.12)
# Requirement already satisfied: executing in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from stack-data->ipython>=5.5.0->pycaret) (1.1.1)
# Requirement already satisfied: asttokens in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.0.8)
# Requirement already satisfied: pure-eval in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (8.1.3)
# Collecting blinker>=1.6.2 (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret)
#   Using cached blinker-1.7.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: entrypoints in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.4)
# Requirement already satisfied: argon2-cffi in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (21.3.0)
# Requirement already satisfied: nbconvert>=5 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (6.5.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.16.0)
# Requirement already satisfied: prometheus-client in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.15.0)
# Requirement already satisfied: lxml in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (4.9.1)
# Requirement already satisfied: beautifulsoup4 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (4.11.1)
# Requirement already satisfied: bleach in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (5.0.1)
# Requirement already satisfied: defusedxml in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.7.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.5.0)
# Requirement already satisfied: tinycss2 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.2.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (2.3.2.post1)
# Requirement already satisfied: webencodings in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.5.1)
# Requirement already satisfied: pycparser in /Users/hugochanteloup/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (2.21)
# Downloading pycaret-3.3.0-py3-none-any.whl (485 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.9/485.9 kB 2.5 MB/s eta 0:00:00a 0:00:01
# Downloading category_encoders-2.6.3-py2.py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 2.9 MB/s eta 0:00:00
# Downloading imbalanced_learn-0.12.0-py3-none-any.whl (257 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.7/257.7 kB 4.6 MB/s eta 0:00:00a 0:00:01
# Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Downloading lightgbm-4.3.0-py3-none-macosx_10_15_x86_64.macosx_11_6_x86_64.macosx_12_5_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 3.9 MB/s eta 0:00:00a 0:00:01
# Downloading plotly-5.19.0-py3-none-any.whl (15.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 4.1 MB/s eta 0:00:0000:0100:01
# Downloading plotly_resampler-0.9.2-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 2.4 MB/s eta 0:00:00
# Downloading tsdownsample-0.1.2-cp310-cp310-macosx_10_7_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 4.1 MB/s eta 0:00:0000:0100:01
# Downloading pmdarima-2.0.4-cp310-cp310-macosx_10_9_x86_64.whl (654 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 654.6/654.6 kB 4.3 MB/s eta 0:00:00a 0:00:01
# Downloading scikit_learn-1.4.1.post1-cp310-cp310-macosx_10_9_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 4.3 MB/s eta 0:00:0000:0100:01
# Downloading sktime-0.26.0-py3-none-any.whl (21.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 4.7 MB/s eta 0:00:0000:0100:01
# Downloading wurlitzer-3.0.3-py3-none-any.whl (7.3 kB)
# Downloading xxhash-3.4.1-cp310-cp310-macosx_10_9_x86_64.whl (31 kB)
# Downloading dash-2.15.0-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 4.1 MB/s eta 0:00:0000:010:01
# Downloading orjson-3.9.14-cp310-cp310-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (253 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.2/253.2 kB 3.9 MB/s eta 0:00:00a 0:00:01
# Downloading scikit_base-0.7.2-py3-none-any.whl (127 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.2/127.2 kB 5.2 MB/s eta 0:00:00
# Downloading flask-3.0.2-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.3/101.3 kB 4.6 MB/s eta 0:00:00
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Using cached blinker-1.7.0-py3-none-any.whl (13 kB)
# Building wheels for collected packages: pyod
#   Building wheel for pyod (setup.py) ... done
#   Created wheel for pyod: filename=pyod-1.1.3-py3-none-any.whl size=190248 sha256=4f5d6a256928bdefcf73320494429dcf612f041c6fd14ea97a027610bbc7a68e
#   Stored in directory: /Users/hugochanteloup/Library/Caches/pip/wheels/05/f8/db/124d43bec122d6ec0ab3713fadfe25ebed8af52ec561682b4e
# Successfully built pyod
# Installing collected packages: kaleido, dash-table, dash-html-components, dash-core-components, xxhash, wurlitzer, tsdownsample, scikit-base, schemdraw, retrying, orjson, joblib, blinker, scikit-learn, plotly, lightgbm, Flask, deprecation, yellowbrick, sktime, scikit-plot, pyod, imbalanced-learn, dash, pmdarima, plotly-resampler, category-encoders, pycaret
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.1
#     Uninstalling joblib-1.1.1:
#       Successfully uninstalled joblib-1.1.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.1
#     Uninstalling scikit-learn-1.3.1:
#       Successfully uninstalled scikit-learn-1.3.1
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.9.0
#     Uninstalling plotly-5.9.0:
#       Successfully uninstalled plotly-5.9.0
#   Attempting uninstall: pyod
#     Found existing installation: pyod 1.1.2
#     Uninstalling pyod-1.1.2:
#       Successfully uninstalled pyod-1.1.2
#   Attempting uninstall: imbalanced-learn
#     Found existing installation: imbalanced-learn 0.9.1
#     Uninstalling imbalanced-learn-0.9.1:
#       Successfully uninstalled imbalanced-learn-0.9.1
#   Attempting uninstall: pmdarima
#     Found existing installation: pmdarima 2.0.1
#     Uninstalling pmdarima-2.0.1:
#       Successfully uninstalled pmdarima-2.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.3.0 requires joblib~=1.1.0, but you have joblib 1.3.2 which is incompatible.
# pandas-profiling 3.3.0 requires statsmodels<0.14,>=0.13.2, but you have statsmodels 0.14.1 which is incompatible.
# streamlit 1.11.1 requires protobuf<4,>=3.12, but you have protobuf 4.25.2 which is incompatible.
# Successfully installed Flask-3.0.2 blinker-1.7.0 category-encoders-2.6.3 dash-2.15.0 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 deprecation-2.1.0 imbalanced-learn-0.12.0 joblib-1.3.2 kaleido-0.2.1 lightgbm-4.3.0 orjson-3.9.14 plotly-5.19.0 plotly-resampler-0.9.2 pmdarima-2.0.4 pycaret-3.3.0 pyod-1.1.3 retrying-1.3.4 schemdraw-0.15 scikit-base-0.7.2 scikit-learn-1.4.1.post1 scikit-plot-0.3.7 sktime-0.26.0 tsdownsample-0.1.2 wurlitzer-3.0.3 xxhash-3.4.1 yellowbrick-1.5
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
# Run second
# If you see an output of pycaret==<some version number>, you're good to go!

#!pip freeze | grep pycaret
# Out:
# pycaret==3.3.0

# %% [markdown]
# ## Data Discovery

# %% [markdown]
# In this challenge we are going to try and detect unwanted accounts (trolls) from a social media moderation dataset.
#
# a) Download [moderation.csv](https://drive.google.com/file/d/1twNqS0rd67DhURv2dZiOyjoeRf3s4q-f/view?usp=sharing) and upload it to Colab.
#
# b) Load the data into a `df` variable.
#
# First off, what are the features and the target?

# %%
import pandas as pd

df = pd.read_csv('moderation.csv')
df
# Out:
#       node_id    email  has_picture_cover  has_linkedin  has_twitter  \
# 0     2220753    gmail                  0             0            0
# 1     2213375    yahoo                  0             0            0
# 2     1991442    gmail                  1             0            0
# 3     1962286  hotmail                  0             0            0
# 4     1968587    gmail                  1             1            0
# ...       ...      ...                ...           ...          ...
# 9995  2002594    gmail                  1             0            0
# 9996  2088858    gmail                  1             0            0
# 9997  2095012  hotmail                  1             1            0
# 9998  2238828    yahoo                  1             0            0
# 9999  2023868    yahoo                  1             0            0
#
#       has_personal_url  has_instagram  is_unwanted  \
# 0                    0              0            1
# 1                    0              0            1
# 2                    0              0            1
# 3                    0              0            1
# 4                    0              0            1
# ...                ...            ...          ...
# 9995                 0              0            0
# 9996                 0              0            0
# 9997                 0              0            0
# 9998                 0              0            0
# 9999                 0              0            0
#
#                                                    tags  \
# 0                                                   NaN
# 1                  Music;SocialMediaMarketing;Marketing
# 2                                                   NaN
# 3     OfficeManagement;CustomerService;Administratio...
# 4     Screenwriting;Fashion;Writing;CopyWriting;Bran...
# ...                                                 ...
# 9995  Entrepreneurship;Startups;Fashion;Technology;B...
# 9996                                                NaN
# 9997  CloudComputing;ITManagement;CyberSecurity;Tech...
# 9998  BusinessOwner;SmallBusiness;Advertising;Entrep...
# 9999  GlobalHealth;MedicalBilling;HealthTech;Healthc...
#
#                                                   goals  nb_chars_in_bio
# 0                                                   NaN              0.0
# 1                                     Job opportunities             46.0
# 2                                                   NaN              0.0
# 3     Explore a career change;Job opportunities;Idea...             25.0
# 4       Mentorship;Job opportunities;Freelance projects            234.0
# ...                                                 ...              ...
# 9995        Grow my business;Funding;Freelance projects             27.0
# 9996                                                NaN              0.0
# 9997                                  Job opportunities              NaN
# 9998  Mentorship;Grow my business;Explore a career c...             33.0
# 9999          Job opportunities;Explore a career change             73.0
#
# [10000 rows x 11 columns]

# %% [markdown]
# <details>
#     <summary><i>Answer:</i></summary>
#
# Features are:
#
# - `node_id` ⇨ internal and unique id of each user
#
# - `email` ⇨ the email used to register (other refers to emails other than the main ones)
#
# - `has_picture_cover` ⇨ has the user added a picture to their profile?
#
# - `has_linkedin` ⇨ has the user added their LinkedIn handle?
#
# - `has_personal_url` ⇨ has the user added a link to their personal url?
#
# - `has_instagram` ⇨ has the user added their Instagram handle?
#
# - `tags` ⇨ the set of tags in the profile, separated by `;`
#
# - `goals` ⇨ the set of goals chosen by the user, separated by `;`
#
# - `nb_chars_in_bio` ⇨ the number of characters in the profile's bio
#
#
# `is_unwanted` is the target.
#
# </details>

# %% [markdown]
# Do we have any missing values in our dataset? (Always a good first step)

# %%
df.isnull().sum()
# Out:
# node_id                 0
# email                   0
# has_picture_cover       0
# has_linkedin            0
# has_twitter             0
# has_personal_url        0
# has_instagram           0
# is_unwanted             0
# tags                 1270
# goals                 991
# nb_chars_in_bio       556
# dtype: int64

# %% [markdown]
# Never forget to properly clean your data!
#
# - Replace NaN values in `nb_chars_in_bio` column by 0.
# - Replace NaN values in `tags` and `goals` column by "".
#
# After, verify that this has been done.

# %% [markdown]
# <details>
#     <summary><i>Hint:</i></summary>
#
# Use `.loc[]` and function `.isnull()`, *or* use `.isnull()` and `.sum()`
#
# </details>

# %%
df['nb_chars_in_bio'] = df['nb_chars_in_bio'].fillna(0)
df['tags'] = df['tags'].fillna('') 
df['goals'] = df['goals'].fillna('')

# %% [markdown]
# c) How many profiles are unwanted? Is the dataset well balanced (i.e. do we have the same number of samples in both classes)?

# %%
df['is_unwanted'].value_counts()
# Out:
# is_unwanted
# 0    9000
# 1    1000
# Name: count, dtype: int64

# %% [markdown]
# d) Do you think that column `node_id` is relevant for our analysis?

# %%
df.drop(columns=['node_id'], inplace=True)

# %% [markdown]
# <details>
#     <summary><i>Hint:</i></summary>
#
# Node_id is a unique identifier,
# we can delete it.
#
# </details>

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# Before we starting create models, we need to thoroughly investigate our features to make sure they are both relevant & in the format that we need.
#
# For categorical features, there are few things we should check. One is unique counts.
#
# a) For the 'email' column, how many providers are there?
#
# Represent their distribution in the form of a histogram.
#
# <details>
# <summary><i>Hint</i></summary>
#     ⟿  Plotly Express has a function "histogram" to make a graph of this distribution: https://plotly.com/python/histograms/
#
# Use the color parameter to distinguish between providers
# </details>

# %%
print(df['email'].nunique())
print(df['email'].unique())
# Out:
# 9
# ['gmail' 'yahoo' 'hotmail' 'outlook' 'other' 'live' 'orange' 'icloud'
#  'aol']

# %%
import plotly.express as px

px.histogram(df, x='email', color='email')

# %% [markdown]
# b) A first simple analysis could be to investigate whether there is a link between a given email provider and the probability of being labeled as 'unwanted'.
#
# Plot this probability in a chart.
#
#
# <details>
# <summary><i>Hint</i></summary>
#     ⟿  use `groupby` and `mean` function to calculate probability of being `is_unwanted` by email provider.
#
#     ⟿  we can use a `bar` chart of Plotly Express : https://plotly.com/python/bar-charts/
# </details>

# %%
df_group_by = df.groupby('email').is_unwanted.mean().reset_index()

px.bar(df_group_by, x='email', y ='is_unwanted')

# %% [markdown]
# <details>
# <summary><i>Explainer</i></summary>
#     Because the column `is_unwanted` is a binary categorical feature, we can simply take the mean of the column to get the ratio of our sample that have a value of '1'. As a result, this ratio gives us the probability of a given breakdown being 'unwanted' in our sample.
#
# </details>

# %% [markdown]
# c) Based on the output of your code above, which email provider is linked to a higher probability of being an 'unwanted' account?
#
# What about the lowest probability?
#
# Based on the probabilities, do you think that email provider is a good predictor of an unwanted account?
#
# If we wanted to investigate this statistically, what test could we do?

# %% [markdown]
# <details>
# <summary><i>Response</i></summary>
#
# - icloud is the provider linked to the highest rate of unwanted accounts.
#
# - On the other hand, it is the other operators, "Other", that are the least associated with undesirable accounts, could be professional emails.
#
# - Overall, the explanatory variable "email" seems to have a low discriminatory power.
#
# - An Chi-Square test could tell us whether or not there are significant differences between email providers.
#
# </details>

# %% [markdown]
# d) Next, lets see if having a `picture cover` the decreases probability of an account being 'unwanted'.
#
# The code below will produce a crosstab that you can use to conduct a Chi-Square test. What conclusion can you draw from the results?
#
# You can also repeat this process with the other boolean variables to see what effect they may have!

# %%
CT = pd.crosstab(index=df['has_picture_cover'], columns=df['is_unwanted'])
CT
# Out:
# is_unwanted           0    1
# has_picture_cover
# 0                  1461  308
# 1                  7539  692

# %%
import scipy.stats as stats

# Perform Chi-squared test
chiRes = stats.chi2_contingency(CT)

# Print out the p-value
print(f'p-value: {chiRes[1]}')
# Out:
# p-value: 3.788507081379461e-30

# %% [markdown]
# e) We want to study the link between `nb_chars_in_bio` and an account being labelled unwanted or not.
#
# Display a boxplot of `nb_chars_in_bio` per `is_unwanted`. What conclusions can you draw?
#
# <details>
# <summary><i>Hint</i></summary>
#     ⟿  The display can use the "box" function of Plotly Express: https://plotly.com/python/bar-plots/
# </details>

# %%
px.box(df, x="nb_chars_in_bio", color = 'is_unwanted')

# %% [markdown]
# <details>
# <summary><i>Answer</i></summary>
#
# We observe that most unwanted accounts filled their bio with less than 50 letters. In other words, the majority of unwanted accounts put at most a short sentence as their bio.
#
# Legitimate users, on the other hand, put in two to three times as much content.
#
# Visually, it looks like this variable has good discriminatory power.
# </details>

# %% [markdown]
# f) The columns `tags` and `goals` contain account information that could also be used to assess whether accounts are unwanted or not. However, the current format is string data that can't easily be parsed.
#
# Let's create two new columns, `nb_tags` and `nb_goals` that contain the counts of how many tags and goals each user has respectively listed in each of the original columns.
#
# <details>
# <summary><i>Hint 1</i></summary>
#
# The function `.count()` counts the number of times a character is found in a string
# </details>
# <br>
#
# <details>
# <summary><i>Hint 2</i></summary>
#
# To apply a string function to a Series, you need to use the attribute `.str` before you chain your function, for example `df[column].str.count(search_string)`
# </details>
# <br>
#
# <details>
# <summary><i>Answer</i></summary>
#
# `df["nb_tags"] = df["tags"].str.count(';') + 1 - (df.tags.str.len() == 0)`
#
# Please ask a TA if you want to walk through the solution!
#
# </details>

# %%
df['nb_tags'] = df['tags'].str.count(';') + 1 - (df.tags.str.len()==0)
df['nb_goals'] = df['goals'].str.count(';') + 1 - (df.tags.str.len()==0)

# %% [markdown]
# # Modeling

# %% [markdown]
# Now that we have performed some feature engineering, we can look into beginning our modelling.
#
# a) First let's only include columns from the original dataframe that will suit our analysis. From `df` create a DataFrame `dataset` that contains the following columns:
#
#  `has_picture_cover`, `has_linkedin`, `has_twitter`, `has_personal_url`, `has_instagram`, `nb_chars_in_bio`, `nb_tags`, `nb_goals`,`is_unwanted`

# %%
dataset = df[
    [
    'has_picture_cover', 
    'has_linkedin',
    'has_twitter',
    'has_personal_url', 
    'has_instagram', 
    'nb_chars_in_bio', 
    'nb_tags', 
    'nb_goals', 
    'is_unwanted'
    ]
]

# %% [markdown]
# b) As we was earlier, the dataset contains 9 times more normal users (`is_unwanted` == 0) than trolls (`is_unwanted` == 1).
#
# Training a model with this bias is very undesirable! This is because, when classifying a new test case, our model will have learnt that an account is likely to be not be a troll 90% of the time. Hence our model will be highly biased to saying accounts aren't trolls.
#
# We can rectify this by resampling our dataset. Often the safest resampling technique is "under-sampling", where we randomly select a subset of the majority class so that we have balanced classes.
#
# Make sure you understand the code below and then execute it.

# %%
# concatenate is_unwanted users and 1000 randomly selected wanted users
dataset = pd.concat([dataset[dataset['is_unwanted']==0].sample(1000),
                     dataset[dataset['is_unwanted']==1]])

dataset['is_unwanted'].value_counts()
# Out:
# is_unwanted
# 0    1000
# 1    1000
# Name: count, dtype: int64

# %% [markdown]
# c) Perform the 80% / 20% split of your dataset with the code below. Again make sure you understand it before running.
#
# What does the `stratify` parameter mean? Why is it useful here?
#
# *Also, note that we didn't split between X, y and train / test.* This will be useful when we use PyCaret at the end of the challenge.

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(dataset
                               ,test_size=0.2
                               ,stratify=dataset['is_unwanted'])

# %% [markdown]
# <details>
# <summary><i>Answer:</i></summary>
# The `stratify = dataset['is_unwanted']` parameter is important because it ensures that the proportion of unwanted individuals remains the when create the train / test sets. An unlucky random slice could result in an unbalanced training / test set, which would hinder our models performance!
# </details>
# <br>

# %% [markdown]
# d) First off, we will create a simple Logistic Regression model. Instantiate and fit a simple Logistic Regression on our train dataset. Be sure to create your X train / test & y train / test.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

X = dataset.drop(columns='is_unwanted')
y = dataset['is_unwanted']

X_train, X_test, y_train, y_test = train_test_split(X, y ,test_size=0.2,random_state=0)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

log_reg = LogisticRegression()

log_reg.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# e) Using our fitted model, generate predictions of the classes from our X_test and save them in a variable called `y_pred`. Use our new `y_pred` variable and our `y_test` to determine the accuracy of our model.

# %%
from sklearn.metrics import accuracy_score

y_pred = log_reg.predict(X_test_scaled)

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7025

# %% [markdown]
# f) Given that we are trying to detect unwanted social media accounts, we might be interested in looking at more than just accuracy in terms of our metrics.
#
# If we think that troll accounts are especially harmful, we might want to make sure that we flag as many as we can (even if that increases the likelihood of incorrectly flagging normal accounts as trolls).
#
# What metric would we check how good our model is at capturing as many real unwanted accounts as possible?
#
# Calulate this score.
#
# <details>
# <summary><i>Hint:</i></summary>
# The recall_score function from sklearn could be usefull.
# </details>

# %%
from sklearn.metrics import recall_score

print("Accuracy:", recall_score(y_test, y_pred))
# Out:
# Accuracy: 0.665

# %% [markdown]
# Our scores are okay, but not amazing!
#
# Deciding between models and tuning the parameters of those models can be a bit of an art, and requires a fair amount of practice to determine which parameters are suitable for a given task.
#
# However, to simplify things, we can use the **PyCaret** library! This will try a whole range of models on our data and show us how they all perform on a number of different metrics in just a few lines of code.

# %% [markdown]
# Complete the following code:
#
# Remember which data variables to use, and to also pay attention to the `normalize` parameter.

# %%
from pycaret.classification import setup

xp = setup(data = # your code here,
           test_data = # your code here,
           target = # your code here,
           normalize = # your code here,
           session_id = # your code here
           )

# %% [markdown]
# e) Screen the PyCaret models and compare their performance by executing cell below.
#
# Which model has the best accuracy?

# %%
from pycaret.classification import compare_models

best_model = compare_models()

# %% [markdown]
# <details>
# <summary><i>Answer:</i></summary>
#
# The best model is likely the `gradient boosting classifier` - gradient boosted models (of various kinds) often perform the best at competitions so this is not surprising!
#
# We should also see that a simple `logistic regression` model performs quite highly, with around 72% accuracy, with scores in a similar range for recall / accuracy.
#
# Looking at the performances of the other classifiers, we can also note:
#
# - Several classifiers offer relatively similar performances at the top of the ranking, which seems to indicate a global convergence towards an optimum across the different models.
#
# - We can observe the Precision/Recall trade-off in the classifiers' scores: models with an especially high score in one should see a corresponding decrease in performance of the other!
# </details>
# <br>

# %% [markdown]
# f) Display matrix confusion for your best model using plot_model function.
#
# (You can refer to the lecture for the correct syntax)

# %%
# your code here

# %% [markdown]
# g) Every model has different parameters that you can fine-tune. As with choosing the intial model, we can use PyCaret to find us the best parameters of our model!
#
# This can be done with a simple call to the `tune_model` function, [described here](https://pycaret.org/tune-model/).
#
# Execute cell below. Has the performance of our best model improved?

# %%
from pycaret.classification import tune_model

best_model_tuned = tune_model(best_model)

# %% [markdown]
# We can also see the exact parameters that were chosing during the model tuning by running the cell below:

# %%
best_model_tuned.get_params()

# %% [markdown]
# <details>
# <summary><i>Answer:</i></summary>
#
# Each fold is a specific split of our data.
#
# If we look at the 'mean' row, the overall performance is not really better. So it seems like tuning our model didn't improve our scores of the default values!
# </details>
# <br>

# %% [markdown]
# h) We might also want to know exactly which features were most important to our model out of the data that was fed in.
#
# To create the features importance graph, call the function `plot_model()` with the model of your choice and add the argument plot="feature".
#
# How do you interpret these values?

# %%
# your code here
