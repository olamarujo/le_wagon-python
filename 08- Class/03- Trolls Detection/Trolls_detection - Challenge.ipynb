# %% [markdown]
#  ![Emil](data:image/png;base64,...)

# %% [markdown]
# # Trolls detection

# %% [markdown]
# # Install Pycaret

# %% [markdown]
# We are going to be using the PyCaret libary later on in this challenge, please run the cell below to install it. It might take a minute or so (if you are asked to restart your runtime, please do so)
#
# Once done, run the second cell and you should see "pycaret==*someversion*".
#
# If that's the case you are good to go! If not, and the output is blank, then raise a ticket with a TA!

# %%
# Run first

#!pip install pycaret

# %%
# Run second
# If you see an output of pycaret==<some version number>, you're good to go!

#!pip freeze | grep pycaret

# %% [markdown]
# ## Data Discovery

# %% [markdown]
# In this challenge we are going to try and detect unwanted accounts (trolls) from a social media moderation dataset.
#
# a) Download [moderation.csv](https://drive.google.com/file/d/1twNqS0rd67DhURv2dZiOyjoeRf3s4q-f/view?usp=sharing) and upload it to Colab.
#
# b) Load the data into a `df` variable.
#
# First off, what are the features and the target?

# %%
import pandas as pd

df = pd.read_csv('moderation.csv')
df
# Out:
#       node_id    email  has_picture_cover  has_linkedin  has_twitter  \
# 0     2220753    gmail                  0             0            0
# 1     2213375    yahoo                  0             0            0
# 2     1991442    gmail                  1             0            0
# 3     1962286  hotmail                  0             0            0
# 4     1968587    gmail                  1             1            0
# ...       ...      ...                ...           ...          ...
# 9995  2002594    gmail                  1             0            0
# 9996  2088858    gmail                  1             0            0
# 9997  2095012  hotmail                  1             1            0
# 9998  2238828    yahoo                  1             0            0
# 9999  2023868    yahoo                  1             0            0
#
#       has_personal_url  has_instagram  is_unwanted  \
# 0                    0              0            1
# 1                    0              0            1
# 2                    0              0            1
# 3                    0              0            1
# 4                    0              0            1
# ...                ...            ...          ...
# 9995                 0              0            0
# 9996                 0              0            0
# 9997                 0              0            0
# 9998                 0              0            0
# 9999                 0              0            0
#
#                                                    tags  \
# 0                                                   NaN
# 1                  Music;SocialMediaMarketing;Marketing
# 2                                                   NaN
# 3     OfficeManagement;CustomerService;Administratio...
# 4     Screenwriting;Fashion;Writing;CopyWriting;Bran...
# ...                                                 ...
# 9995  Entrepreneurship;Startups;Fashion;Technology;B...
# 9996                                                NaN
# 9997  CloudComputing;ITManagement;CyberSecurity;Tech...
# 9998  BusinessOwner;SmallBusiness;Advertising;Entrep...
# 9999  GlobalHealth;MedicalBilling;HealthTech;Healthc...
#
#                                                   goals  nb_chars_in_bio
# 0                                                   NaN              0.0
# 1                                     Job opportunities             46.0
# 2                                                   NaN              0.0
# 3     Explore a career change;Job opportunities;Idea...             25.0
# 4       Mentorship;Job opportunities;Freelance projects            234.0
# ...                                                 ...              ...
# 9995        Grow my business;Funding;Freelance projects             27.0
# 9996                                                NaN              0.0
# 9997                                  Job opportunities              NaN
# 9998  Mentorship;Grow my business;Explore a career c...             33.0
# 9999          Job opportunities;Explore a career change             73.0
#
# [10000 rows x 11 columns]

# %% [markdown]
# <details>
#     <summary><i>Answer:</i></summary>
#
# Features are:
#
# - `node_id` ⇨ internal and unique id of each user
#
# - `email` ⇨ the email used to register (other refers to emails other than the main ones)
#
# - `has_picture_cover` ⇨ has the user added a picture to their profile?
#
# - `has_linkedin` ⇨ has the user added their LinkedIn handle?
#
# - `has_personal_url` ⇨ has the user added a link to their personal url?
#
# - `has_instagram` ⇨ has the user added their Instagram handle?
#
# - `tags` ⇨ the set of tags in the profile, separated by `;`
#
# - `goals` ⇨ the set of goals chosen by the user, separated by `;`
#
# - `nb_chars_in_bio` ⇨ the number of characters in the profile's bio
#
#
# `is_unwanted` is the target.
#
# </details>

# %% [markdown]
# Do we have any missing values in our dataset? (Always a good first step)

# %%
df.isnull().sum()
# Out:
# node_id                 0
# email                   0
# has_picture_cover       0
# has_linkedin            0
# has_twitter             0
# has_personal_url        0
# has_instagram           0
# is_unwanted             0
# tags                 1270
# goals                 991
# nb_chars_in_bio       556
# dtype: int64

# %% [markdown]
# Never forget to properly clean your data!
#
# - Replace NaN values in `nb_chars_in_bio` column by 0.
# - Replace NaN values in `tags` and `goals` column by "".
#
# After, verify that this has been done.

# %% [markdown]
# <details>
#     <summary><i>Hint:</i></summary>
#
# Use `.loc[]` and function `.isnull()`, *or* use `.isnull()` and `.sum()`
#
# </details>

# %%
df['nb_chars_in_bio'] = df['nb_chars_in_bio'].fillna(0)
df['tags'] = df['tags'].fillna('') 
df['goals'] = df['goals'].fillna('')

# %% [markdown]
# c) How many profiles are unwanted? Is the dataset well balanced (i.e. do we have the same number of samples in both classes)?

# %%
df['is_unwanted'].value_counts()
# Out:
# is_unwanted
# 0    9000
# 1    1000
# Name: count, dtype: int64

# %% [markdown]
# d) Do you think that column `node_id` is relevant for our analysis?

# %%
df.drop(columns=['node_id'], inplace=True)

# %% [markdown]
# <details>
#     <summary><i>Hint:</i></summary>
#
# Node_id is a unique identifier,
# we can delete it.
#
# </details>

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# Before we starting create models, we need to thoroughly investigate our features to make sure they are both relevant & in the format that we need.
#
# For categorical features, there are few things we should check. One is unique counts.
#
# a) For the 'email' column, how many providers are there?
#
# Represent their distribution in the form of a histogram.
#
# <details>
# <summary><i>Hint</i></summary>
#     ⟿  Plotly Express has a function "histogram" to make a graph of this distribution: https://plotly.com/python/histograms/
#
# Use the color parameter to distinguish between providers
# </details>

# %%
print(df['email'].nunique())
print(df['email'].unique())
# Out:
# 9
# ['gmail' 'yahoo' 'hotmail' 'outlook' 'other' 'live' 'orange' 'icloud'
#  'aol']

# %%
import plotly.express as px

px.histogram(df, x='email', color='email')

# %% [markdown]
# b) A first simple analysis could be to investigate whether there is a link between a given email provider and the probability of being labeled as 'unwanted'.
#
# Plot this probability in a chart.
#
#
# <details>
# <summary><i>Hint</i></summary>
#     ⟿  use `groupby` and `mean` function to calculate probability of being `is_unwanted` by email provider.
#
#     ⟿  we can use a `bar` chart of Plotly Express : https://plotly.com/python/bar-charts/
# </details>

# %%
df_group_by = df.groupby('email').is_unwanted.mean().reset_index()

px.bar(df_group_by, x='email', y ='is_unwanted')

# %% [markdown]
# <details>
# <summary><i>Explainer</i></summary>
#     Because the column `is_unwanted` is a binary categorical feature, we can simply take the mean of the column to get the ratio of our sample that have a value of '1'. As a result, this ratio gives us the probability of a given breakdown being 'unwanted' in our sample.
#
# </details>

# %% [markdown]
# c) Based on the output of your code above, which email provider is linked to a higher probability of being an 'unwanted' account?
#
# What about the lowest probability?
#
# Based on the probabilities, do you think that email provider is a good predictor of an unwanted account?
#
# If we wanted to investigate this statistically, what test could we do?

# %% [markdown]
# <details>
# <summary><i>Response</i></summary>
#
# - icloud is the provider linked to the highest rate of unwanted accounts.
#
# - On the other hand, it is the other operators, "Other", that are the least associated with undesirable accounts, could be professional emails.
#
# - Overall, the explanatory variable "email" seems to have a low discriminatory power.
#
# - An Chi-Square test could tell us whether or not there are significant differences between email providers.
#
# </details>

# %% [markdown]
# d) Next, lets see if having a `picture cover` the decreases probability of an account being 'unwanted'.
#
# The code below will produce a crosstab that you can use to conduct a Chi-Square test. What conclusion can you draw from the results?
#
# You can also repeat this process with the other boolean variables to see what effect they may have!

# %%
CT = pd.crosstab(index=df['has_picture_cover'], columns=df['is_unwanted'])
CT
# Out:
# is_unwanted           0    1
# has_picture_cover
# 0                  1461  308
# 1                  7539  692

# %%
import scipy.stats as stats

# Perform Chi-squared test
chiRes = stats.chi2_contingency(CT)

# Print out the p-value
print(f'p-value: {chiRes[1]}')
# Out:
# p-value: 3.788507081379461e-30

# %% [markdown]
# e) We want to study the link between `nb_chars_in_bio` and an account being labelled unwanted or not.
#
# Display a boxplot of `nb_chars_in_bio` per `is_unwanted`. What conclusions can you draw?
#
# <details>
# <summary><i>Hint</i></summary>
#     ⟿  The display can use the "box" function of Plotly Express: https://plotly.com/python/bar-plots/
# </details>

# %%
px.box(df, x="nb_chars_in_bio", color = 'is_unwanted')

# %% [markdown]
# <details>
# <summary><i>Answer</i></summary>
#
# We observe that most unwanted accounts filled their bio with less than 50 letters. In other words, the majority of unwanted accounts put at most a short sentence as their bio.
#
# Legitimate users, on the other hand, put in two to three times as much content.
#
# Visually, it looks like this variable has good discriminatory power.
# </details>

# %% [markdown]
# f) The columns `tags` and `goals` contain account information that could also be used to assess whether accounts are unwanted or not. However, the current format is string data that can't easily be parsed.
#
# Let's create two new columns, `nb_tags` and `nb_goals` that contain the counts of how many tags and goals each user has respectively listed in each of the original columns.
#
# <details>
# <summary><i>Hint 1</i></summary>
#
# The function `.count()` counts the number of times a character is found in a string
# </details>
# <br>
#
# <details>
# <summary><i>Hint 2</i></summary>
#
# To apply a string function to a Series, you need to use the attribute `.str` before you chain your function, for example `df[column].str.count(search_string)`
# </details>
# <br>
#
# <details>
# <summary><i>Answer</i></summary>
#
# `df["nb_tags"] = df["tags"].str.count(';') + 1 - (df.tags.str.len() == 0)`
#
# Please ask a TA if you want to walk through the solution!
#
# </details>

# %%
df['nb_tags'] = df['tags'].str.count(';') + 1 - (df.tags.str.len()==0)
df['nb_goals'] = df['goals'].str.count(';') + 1 - (df.tags.str.len()==0)

# %% [markdown]
# # Modeling

# %% [markdown]
# Now that we have performed some feature engineering, we can look into beginning our modelling.
#
# a) First let's only include columns from the original dataframe that will suit our analysis. From `df` create a DataFrame `dataset` that contains the following columns:
#
#  `has_picture_cover`, `has_linkedin`, `has_twitter`, `has_personal_url`, `has_instagram`, `nb_chars_in_bio`, `nb_tags`, `nb_goals`,`is_unwanted`

# %%
dataset = df[
    [
    'has_picture_cover', 
    'has_linkedin',
    'has_twitter',
    'has_personal_url', 
    'has_instagram', 
    'nb_chars_in_bio', 
    'nb_tags', 
    'nb_goals', 
    'is_unwanted'
    ]
]

# %% [markdown]
# b) As we was earlier, the dataset contains 9 times more normal users (`is_unwanted` == 0) than trolls (`is_unwanted` == 1).
#
# Training a model with this bias is very undesirable! This is because, when classifying a new test case, our model will have learnt that an account is likely to be not be a troll 90% of the time. Hence our model will be highly biased to saying accounts aren't trolls.
#
# We can rectify this by resampling our dataset. Often the safest resampling technique is "under-sampling", where we randomly select a subset of the majority class so that we have balanced classes.
#
# Make sure you understand the code below and then execute it.

# %%
# concatenate is_unwanted users and 1000 randomly selected wanted users
dataset = pd.concat([dataset[dataset['is_unwanted']==0].sample(1000),
                     dataset[dataset['is_unwanted']==1]])

dataset['is_unwanted'].value_counts()
# Out:
# is_unwanted
# 0    1000
# 1    1000
# Name: count, dtype: int64

# %% [markdown]
# c) Perform the 80% / 20% split of your dataset with the code below. Again make sure you understand it before running.
#
# What does the `stratify` parameter mean? Why is it useful here?
#
# *Also, note that we didn't split between X, y and train / test.* This will be useful when we use PyCaret at the end of the challenge.

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(dataset
                               ,test_size=0.2
                               ,stratify=dataset['is_unwanted'])

# %% [markdown]
# <details>
# <summary><i>Answer:</i></summary>
# The `stratify = dataset['is_unwanted']` parameter is important because it ensures that the proportion of unwanted individuals remains the when create the train / test sets. An unlucky random slice could result in an unbalanced training / test set, which would hinder our models performance!
# </details>
# <br>

# %% [markdown]
# d) First off, we will create a simple Logistic Regression model. Instantiate and fit a simple Logistic Regression on our train dataset. Be sure to create your X train / test & y train / test.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

X = dataset.drop(columns='is_unwanted')
y = dataset['is_unwanted']

X_train, X_test, y_train, y_test = train_test_split(X, y ,test_size=0.2,random_state=0)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

log_reg = LogisticRegression()

log_reg.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# e) Using our fitted model, generate predictions of the classes from our X_test and save them in a variable called `y_pred`. Use our new `y_pred` variable and our `y_test` to determine the accuracy of our model.

# %%
from sklearn.metrics import accuracy_score

y_pred = log_reg.predict(X_test_scaled)

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7075

# %% [markdown]
# f) Given that we are trying to detect unwanted social media accounts, we might be interested in looking at more than just accuracy in terms of our metrics.
#
# If we think that troll accounts are especially harmful, we might want to make sure that we flag as many as we can (even if that increases the likelihood of incorrectly flagging normal accounts as trolls).
#
# What metric would we check how good our model is at capturing as many real unwanted accounts as possible?
#
# Calulate this score.
#
# <details>
# <summary><i>Hint:</i></summary>
# The recall_score function from sklearn could be usefull.
# </details>

# %%
from sklearn.metrics import recall_score

print("Accuracy:", recall_score(y_test, y_pred))
# Out:
# Accuracy: 0.705

# %% [markdown]
# Our scores are okay, but not amazing!
#
# Deciding between models and tuning the parameters of those models can be a bit of an art, and requires a fair amount of practice to determine which parameters are suitable for a given task.
#
# However, to simplify things, we can use the **PyCaret** library! This will try a whole range of models on our data and show us how they all perform on a number of different metrics in just a few lines of code.

# %% [markdown]
# Complete the following code:
#
# Remember which data variables to use, and to also pay attention to the `normalize` parameter.

# %%
from pycaret.classification import setup

xp = setup(
    data = train,
    test_data = test,
    target = 'is_unwanted',
    normalize = True,
    session_id = 0,
    n_jobs=-1,         
    use_gpu=False,     
    log_experiment=False,         
    verbose=False 
)

# %% [markdown]
# e) Screen the PyCaret models and compare their performance by executing cell below.
#
# Which model has the best accuracy?

# %%
from pycaret.classification import compare_models

best_model = compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              18:35:14
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# #T_910ca th {
#   text-align: left;
# }
# #T_910ca_row0_col0, #T_910ca_row0_col1, #T_910ca_row0_col2, #T_910ca_row0_col3, #T_910ca_row0_col4, #T_910ca_row0_col5, #T_910ca_row0_col6, #T_910ca_row0_col7, #T_910ca_row0_col8, #T_910ca_row1_col0, #T_910ca_row1_col1, #T_910ca_row1_col2, #T_910ca_row1_col3, #T_910ca_row1_col4, #T_910ca_row1_col5, #T_910ca_row1_col6, #T_910ca_row1_col7, #T_910ca_row1_col8, #T_910ca_row2_col0, #T_910ca_row2_col1, #T_910ca_row2_col2, #T_910ca_row2_col3, #T_910ca_row2_col4, #T_910ca_row2_col5, #T_910ca_row2_col6, #T_910ca_row2_col7, #T_910ca_row2_col8, #T_910ca_row3_col0, #T_910ca_row3_col1, #T_910ca_row3_col2, #T_910ca_row3_col3, #T_910ca_row3_col4, #T_910ca_row3_col5, #T_910ca_row3_col6, #T_910ca_row3_col7, #T_910ca_row3_col8, #T_910ca_row4_col0, #T_910ca_row4_col1, #T_910ca_row4_col2, #T_910ca_row4_col3, #T_910ca_row4_col4, #T_910ca_row4_col5, #T_910ca_row4_col6, #T_910ca_row4_col7, #T_910ca_row4_col8, #T_910ca_row5_col0, #T_910ca_row5_col1, #T_910ca_row5_col2, #T_910ca_row5_col3, #T_910ca_row5_col4, #T_910ca_row5_col5, #T_910ca_row5_col6, #T_910ca_row5_col7, #T_910ca_row5_col8, #T_910ca_row6_col0, #T_910ca_row6_col1, #T_910ca_row6_col2, #T_910ca_row6_col3, #T_910ca_row6_col4, #T_910ca_row6_col5, #T_910ca_row6_col6, #T_910ca_row6_col7, #T_910ca_row6_col8, #T_910ca_row7_col0, #T_910ca_row7_col1, #T_910ca_row7_col2, #T_910ca_row7_col3, #T_910ca_row7_col4, #T_910ca_row7_col5, #T_910ca_row7_col6, #T_910ca_row7_col7, #T_910ca_row7_col8, #T_910ca_row8_col0, #T_910ca_row8_col1, #T_910ca_row8_col2, #T_910ca_row8_col3, #T_910ca_row8_col4, #T_910ca_row8_col5, #T_910ca_row8_col6, #T_910ca_row8_col7, #T_910ca_row8_col8, #T_910ca_row9_col0, #T_910ca_row9_col1, #T_910ca_row9_col2, #T_910ca_row9_col3, #T_910ca_row9_col4, #T_910ca_row9_col5, #T_910ca_row9_col6, #T_910ca_row9_col7, #T_910ca_row9_col8, #T_910ca_row10_col0, #T_910ca_row10_col1, #T_910ca_row10_col2, #T_910ca_row10_col3, #T_910ca_row10_col4, #T_910ca_row10_col5, #T_910ca_row10_col6, #T_910ca_row10_col7, #T_910ca_row10_col8, #T_910ca_row11_col0, #T_910ca_row11_col1, #T_910ca_row11_col2, #T_910ca_row11_col3, #T_910ca_row11_col4, #T_910ca_row11_col5, #T_910ca_row11_col6, #T_910ca_row11_col7, #T_910ca_row11_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_910ca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_910ca_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_910ca_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_910ca_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_910ca_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_910ca_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_910ca_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_910ca_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_910ca_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_910ca_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_910ca_level0_row0" class="row_heading level0 row0" >ada</th>
#       <td id="T_910ca_row0_col0" class="data row0 col0" >Ada Boost Classifier</td>
#       <td id="T_910ca_row0_col1" class="data row0 col1" >0.7094</td>
#       <td id="T_910ca_row0_col2" class="data row0 col2" >0.7650</td>
#       <td id="T_910ca_row0_col3" class="data row0 col3" >0.7075</td>
#       <td id="T_910ca_row0_col4" class="data row0 col4" >0.7114</td>
#       <td id="T_910ca_row0_col5" class="data row0 col5" >0.7084</td>
#       <td id="T_910ca_row0_col6" class="data row0 col6" >0.4188</td>
#       <td id="T_910ca_row0_col7" class="data row0 col7" >0.4201</td>
#       <td id="T_910ca_row0_col8" class="data row0 col8" >0.0480</td>
#     </tr>
#     <tr>
#       <th id="T_910ca_level0_row1" class="row_heading level0 row1" >lr</th>
#       <td id="T_910ca_row1_col0" class="data row1 col0" >Logistic Regression</td>
#       <td id="T_910ca_row1_col1" class="data row1 col1" >0.7075</td>
#       <td id="T_910ca_row1_col2" class="data row1 col2" >0.7681</td>
#       <td id="T_910ca_row1_col3" class="data row1 col3" >0.7325</td>
#       <td id="T_910ca_row1_col4" class="data row1 col4" >0.6988</td>
#       <td id="T_910ca_row1_col5" class="data row1 col5" >0.7146</td>
#       <td id="T_910ca_row1_col6" class="data row1 col6" >0.4150</td>
#       <td id="T_910ca_row1_col7" class="data row1 col7" >0.4164</td>
#       <td id="T_910ca_row1_col8" class="data row1 col8" >0.3570</td>
#     </tr>
#     <tr>
#       <th id="T_910ca_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_910ca_row2_col0" class="data row2 col0" >Ridge Classifier</td>
#       <td id="T_910ca_row2_col1" class="data row2 col1" >0.7069</td>
#       <td id="T_910ca_row2_col2" class="data row2 col2" >0.7677</td>
#       <td id="T_910ca_row2_col3" class="data row2 col3" >0.7338</td>
#       <td id="T_910ca_row2_col4" class="data row2 col4" >0.6972</td>
#       <td id="T_910ca_row2_col5" class="data row2 col5" >0.7144</td>
#       <td id="T_910ca_row2_col6" class="data row2 col6" >0.4137</td>
#       <td id="T_910ca_row2_col7" class="data row2 col7" >0.4152</td>
#       <td id="T_910ca_row2_col8" class="data row2 col8" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_910ca_level0_row3" class="row_heading level0 row3" >lda</th>
#       <td id="T_910ca_row3_col0" class="data row3 col0" >Linear Discriminant Analysis</td>
#       <td id="T_910ca_row3_col1" class="data row3 col1" >0.7069</td>
#       <td id="T_910ca_row3_col2" class="data row3 col2" >0.7678</td>
#       <td id="T_910ca_row3_col3" class="data row3 col3" >0.7338</td>
#       <td id="T_910ca_row3_col4" class="data row3 col4" >0.6972</td>
#       <td id="T_910ca_row3_col5" class="data row3 col5" >0.7144</td>
#       <td id="T_910ca_row3_col6" class="data row3 col6" >0.4137</td>
#       <td id="T_910ca_row3_col7" class="data row3 col7" >0.4152</td>
#       <td id="T_910ca_row3_col8" class="data row3 col8" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_910ca_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_910ca_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_910ca_row4_col1" class="data row4 col1" >0.7019</td>
#       <td id="T_910ca_row4_col2" class="data row4 col2" >0.7592</td>
#       <td id="T_910ca_row4_col3" class="data row4 col3" >0.6838</td>
#       <td id="T_910ca_row4_col4" class="data row4 col4" >0.7112</td>
#       <td id="T_910ca_row4_col5" class="data row4 col5" >0.6957</td>
#       <td id="T_910ca_row4_col6" class="data row4 col6" >0.4037</td>
#       <td id="T_910ca_row4_col7" class="data row4 col7" >0.4058</td>
#       <td id="T_910ca_row4_col8" class="data row4 col8" >0.0600</td>
#     </tr>
#     <tr>
#       <th id="T_910ca_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_910ca_row5_col0" class="data row5 col0" >K Neighbors Classifier</td>
#       <td id="T_910ca_row5_col1" class="data row5 col1" >0.6937</td>
#       <td id="T_910ca_row5_col2" class="data row5 col2" >0.7376</td>
#       <td id="T_910ca_row5_col3" class="data row5 col3" >0.6725</td>
#       <td id="T_910ca_row5_col4" class="data row5 col4" >0.7030</td>
#       <td id="T_910ca_row5_col5" class="data row5 col5" >0.6862</td>
#       <td id="T_910ca_row5_col6" class="data row5 col6" >0.3875</td>
#       <td id="T_910ca_row5_col7" class="data row5 col7" >0.3892</td>
#       <td id="T_910ca_row5_col8" class="data row5 col8" >0.0290</td>
#     </tr>
#     <tr>
#       <th id="T_910ca_level0_row6" class="row_heading level0 row6" >svm</th>
#       <td id="T_910ca_row6_col0" class="data row6 col0" >SVM - Linear Kernel</td>
#       <td id="T_910ca_row6_col1" class="data row6 col1" >0.6825</td>
#       <td id="T_910ca_row6_col2" class="data row6 col2" >0.7413</td>
#       <td id="T_910ca_row6_col3" class="data row6 col3" >0.7162</td>
#       <td id="T_910ca_row6_col4" class="data row6 col4" >0.6754</td>
#       <td id="T_910ca_row6_col5" class="data row6 col5" >0.6
# Processing:   0%|          | 0/61 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 3
#       1 from pycaret.classification import compare_models
# ----> 3 best_model = compare_models()
#
# File ~/miniconda3/envs/pycaret-env/lib/python3.11/site-packages/pycaret/utils/generic.py:964, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     962     if globals_d[name] is None:
#     963         raise ValueError(message)
# --> 964 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/pycaret-env/lib/python3.11/site-packages/pycaret/classification/functional.py:814, in compare_models(include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, engine, verbose, parallel)
#     672 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#     673 def compare_models(
#     674     include: Optional[List[Union[str, Any]]] = None,
#    (...)    690     parallel: Optional[ParallelBackend] = None,
#     691 ) -> Union[Any, List[Any]]:
#     692     """
#     693     This function trains and evaluates performance of all estimators available in the
#     694     model library using cross validation. The output of this function is a score grid
#    (...)    811     - No models are logged in ``MLFlow`` when ``cross_validation`` parameter is False.
#     812     """
# --> 814     return _CURRENT_EXPERIMENT.compare_models(
#     815         include=include,
#     816         exclude=exclude,
#     817         fold=fold,
#     818         round=round,
#     819         cross_validation=cross_validation,
#     820         sort=sort,
#     821         n_select=n_select,
#     822         budget_time=budget_time,
#     823         turbo=turbo,
#     824         errors=errors,
#     825         fit_kwargs=fit_kwargs,
#     826         groups=groups,
#     827         experiment_custom_tags=experiment_custom_tags,
#     828         probability_threshold=probability_threshold,
#     829         engine=engine,
#     830         verbose=verbose,
#     831         parallel=parallel,
#     832     )
#
# File ~/miniconda3/envs/pycaret-env/lib/python3.11/site-packages/pycaret/classification/oop.py:1180, in ClassificationExperiment.compare_models(self, include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, engine, verbose, parallel)
#    1177         self._set_engine(estimator=estimator, engine=eng, severity="error")
#    1179 try:
# -> 1180     return_values = super().compare_models(
#    1181         include=include,
#    1182         exclude=exclude,
#    1183         fold=fold,
#    1184         round=round,
#    1185         cross_validation=cross_validation,
#    1186         sort=sort,
#    1187         n_select=n_select,
#    1188         budget_time=budget_time,
#    1189         turbo=turbo,
#    1190         errors=errors,
#    1191         fit_kwargs=fit_kwargs,
#    1192         groups=groups,
#    1193         experiment_custom_tags=experiment_custom_tags,
#    1194         verbose=verbose,
#    1195         probability_threshold=probability_threshold,
#    1196         parallel=parallel,
#    1197         caller_params=caller_params,
#    1198     )
#    1199 finally:
#    1200     if engine is not None:
#    1201         # Reset the models back to the default engines
#
# File ~/miniconda3/envs/pycaret-env/lib/python3.11/site-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:794, in _SupervisedExperiment.compare_models(self, include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, verbose, parallel, caller_params)
#     791 results_columns_to_ignore = ["Object", "runtime", "cutoff"]
#     793 try:
# --> 794     model, model_fit_time = self._create_model(**create_model_args)
#     795     model_results = self.pull(pop=True)
#     796     assert (
#     797         np.sum(
#     798             model_results.drop(
#    (...)    802         != 0.0
#     803     )
#
# File ~/miniconda3/envs/pycaret-env/lib/python3.11/site-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:1533, in _SupervisedExperiment._create_model(self, estimator, fold, round, cross_validation, predict, fit_kwargs, groups, refit, probability_threshold, experiment_custom_tags, verbose, system, add_to_model_list, X_train_data, y_train_data, metrics, display, model_only, return_train_score, error_score, **kwargs)
#    1530         return model, model_fit_time
#    1531     return model
# -> 1533 model, model_fit_time, model_results, _ = self._create_model_with_cv(
#    1534     model=model,
#    1535     data_X=data_X,
#    1536     data_y=data_y,
#    1537     fit_kwargs=fit_kwargs,
#    1538     round=round,
#    1539     cv=cv,
#    1540     groups=groups,
#    1541     metrics=metrics,
#    1542     refit=refit,
#    1543     system=system,
#    1544     display=display,
#    1545     error_score=error_score,
#    1546     return_train_score=return_train_score,
#    1547 )
#    1549 # end runtime
#    1550 runtime_end = time.time()
#
# File ~/miniconda3/envs/pycaret-env/lib/python3.11/site-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:1126, in _SupervisedExperiment._create_model_with_cv(self, model, data_X, data_y, fit_kwargs, round, cv, groups, metrics, refit, system, display, error_score, return_train_score)
#    1124     model_fit_start = time.time()
#    1125     with redirect_output(self.logger):
# -> 1126         scores = cross_validate(
#    1127             pipeline_with_model,
#    1128             data_X,
#    1129             data_y,
#    1130             cv=cv,
#    1131             groups=groups,
#    1132             scoring=metrics_dict,
#    1133             params=fit_kwargs,
#    1134             n_jobs=n_jobs,
#    1135             return_train_score=return_train_score,
#    1136             error_score=error_score,
#    1137         )
#    1139 model_fit_end = time.time()
#    1140 model_fit_time = np.array(model_fit_end - model_fit_start).round(2)
#
# File ~/miniconda3/envs/pycaret-env/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~/miniconda3/envs/pycaret-env/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:430, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     427 # We clone the estimator to make sure that all the folds are
#     428 # independent, and that it is pickle-able.
#     429 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 430 results = parallel(
#     431     delayed(_fit_and_score)(
#     432         clone(estimator),
#     433         X,
#     434         y,
#     435         scorer=scorers,
#     436         train=train,
#     437         test=test,
#     438         verbose=verbose,
#     439         parameters=None,
#     440         fit_params=routed_params.estimator.fit,
#     441         score_params=routed_params.scorer.score,
#     442         return_train_score=return_train_score,
#     443         return_times=True,
#     444         return_estimator=return_estimator,
#     445         error_score=error_score,
#     446     )
#     447     for train, test in indices
#     448 )
#     450 _warn_or_raise_about_fit_failures(results, error_score)
#     452 # For callable scoring, the return type is only know after calling. If the
#     453 # return type is a dictionary, the error scores can now be inserted with
#     454 # the correct key.
#
# File ~/miniconda3/envs/pycaret-env/lib/python3.11/site-packages/sklearn/utils/parallel.py:67, in Parallel.__call__(self, iterable)
#      62 config = get_config()
#      63 iterable_with_config = (
#      64     (_with_config(delayed_func, config), args, kwargs)
#      65     for delayed_func, args, kwargs in iterable
#      66 )
# ---> 67 return super().__call__(iterable_with_config)
#
# File ~/miniconda3/envs/pycaret-env/lib/python3.11/site-packages/joblib/parallel.py:1952, in Parallel.__call__(self, iterable)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File ~/miniconda3/envs/pycaret-env/lib/python3.11/site-packages/joblib/parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1592     yield
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#    1601     self._exception = True
#
# File ~/miniconda3/envs/pycaret-env/lib/python3.11/site-packages/joblib/parallel.py:1707, in Parallel._retrieve(self)
#    1702 # If the next job is not ready for retrieval yet, we just wait for
#    1703 # async callbacks to progress.
#    1704 if ((len(self._jobs) == 0) or
#    1705     (self._jobs[0].get_status(
#    1706         timeout=self.timeout) == TASK_PENDING)):
# -> 1707     time.sleep(0.01)
#    1708     continue
#    1710 # We need to be careful: the job list can be filling up as
#    1711 # we empty it and Python list are not thread-safe by
#    1712 # default hence the use of the lock
#
# KeyboardInterrupt:

# %% [markdown]
# <details>
# <summary><i>Answer:</i></summary>
#
# The best model is likely the `gradient boosting classifier` - gradient boosted models (of various kinds) often perform the best at competitions so this is not surprising!
#
# We should also see that a simple `logistic regression` model performs quite highly, with around 72% accuracy, with scores in a similar range for recall / accuracy.
#
# Looking at the performances of the other classifiers, we can also note:
#
# - Several classifiers offer relatively similar performances at the top of the ranking, which seems to indicate a global convergence towards an optimum across the different models.
#
# - We can observe the Precision/Recall trade-off in the classifiers' scores: models with an especially high score in one should see a corresponding decrease in performance of the other!
# </details>
# <br>

# %% [markdown]
# f) Display matrix confusion for your best model using plot_model function.
#
# (You can refer to the lecture for the correct syntax)

# %%
from pycaret.classification import plot_model

plot_model(best_model, plot='confusion_matrix')

# %% [markdown]
# g) Every model has different parameters that you can fine-tune. As with choosing the intial model, we can use PyCaret to find us the best parameters of our model!
#
# This can be done with a simple call to the `tune_model` function, [described here](https://pycaret.org/tune-model/).
#
# Execute cell below. Has the performance of our best model improved?

# %%
from pycaret.classification import tune_model

best_model_tuned = tune_model(best_model)
# Out:
# <style type="text/css">
# #T_dcdc0_row10_col0, #T_dcdc0_row10_col1, #T_dcdc0_row10_col2, #T_dcdc0_row10_col3, #T_dcdc0_row10_col4, #T_dcdc0_row10_col5, #T_dcdc0_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_dcdc0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dcdc0_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_dcdc0_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_dcdc0_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_dcdc0_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_dcdc0_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_dcdc0_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_dcdc0_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dcdc0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dcdc0_row0_col0" class="data row0 col0" >0.7500</td>
#       <td id="T_dcdc0_row0_col1" class="data row0 col1" >0.8267</td>
#       <td id="T_dcdc0_row0_col2" class="data row0 col2" >0.7750</td>
#       <td id="T_dcdc0_row0_col3" class="data row0 col3" >0.7381</td>
#       <td id="T_dcdc0_row0_col4" class="data row0 col4" >0.7561</td>
#       <td id="T_dcdc0_row0_col5" class="data row0 col5" >0.5000</td>
#       <td id="T_dcdc0_row0_col6" class="data row0 col6" >0.5006</td>
#     </tr>
#     <tr>
#       <th id="T_dcdc0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dcdc0_row1_col0" class="data row1 col0" >0.6938</td>
#       <td id="T_dcdc0_row1_col1" class="data row1 col1" >0.7292</td>
#       <td id="T_dcdc0_row1_col2" class="data row1 col2" >0.6875</td>
#       <td id="T_dcdc0_row1_col3" class="data row1 col3" >0.6962</td>
#       <td id="T_dcdc0_row1_col4" class="data row1 col4" >0.6918</td>
#       <td id="T_dcdc0_row1_col5" class="data row1 col5" >0.3875</td>
#       <td id="T_dcdc0_row1_col6" class="data row1 col6" >0.3875</td>
#     </tr>
#     <tr>
#       <th id="T_dcdc0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dcdc0_row2_col0" class="data row2 col0" >0.7312</td>
#       <td id="T_dcdc0_row2_col1" class="data row2 col1" >0.7968</td>
#       <td id="T_dcdc0_row2_col2" class="data row2 col2" >0.7875</td>
#       <td id="T_dcdc0_row2_col3" class="data row2 col3" >0.7079</td>
#       <td id="T_dcdc0_row2_col4" class="data row2 col4" >0.7456</td>
#       <td id="T_dcdc0_row2_col5" class="data row2 col5" >0.4625</td>
#       <td id="T_dcdc0_row2_col6" class="data row2 col6" >0.4655</td>
#     </tr>
#     <tr>
#       <th id="T_dcdc0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dcdc0_row3_col0" class="data row3 col0" >0.6688</td>
#       <td id="T_dcdc0_row3_col1" class="data row3 col1" >0.7230</td>
#       <td id="T_dcdc0_row3_col2" class="data row3 col2" >0.6250</td>
#       <td id="T_dcdc0_row3_col3" class="data row3 col3" >0.6849</td>
#       <td id="T_dcdc0_row3_col4" class="data row3 col4" >0.6536</td>
#       <td id="T_dcdc0_row3_col5" class="data row3 col5" >0.3375</td>
#       <td id="T_dcdc0_row3_col6" class="data row3 col6" >0.3388</td>
#     </tr>
#     <tr>
#       <th id="T_dcdc0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dcdc0_row4_col0" class="data row4 col0" >0.7000</td>
#       <td id="T_dcdc0_row4_col1" class="data row4 col1" >0.7468</td>
#       <td id="T_dcdc0_row4_col2" class="data row4 col2" >0.6375</td>
#       <td id="T_dcdc0_row4_col3" class="data row4 col3" >0.7286</td>
#       <td id="T_dcdc0_row4_col4" class="data row4 col4" >0.6800</td>
#       <td id="T_dcdc0_row4_col5" class="data row4 col5" >0.4000</td>
#       <td id="T_dcdc0_row4_col6" class="data row4 col6" >0.4032</td>
#     </tr>
#     <tr>
#       <th id="T_dcdc0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dcdc0_row5_col0" class="data row5 col0" >0.6938</td>
#       <td id="T_dcdc0_row5_col1" class="data row5 col1" >0.7591</td>
#       <td id="T_dcdc0_row5_col2" class="data row5 col2" >0.7250</td>
#       <td id="T_dcdc0_row5_col3" class="data row5 col3" >0.6824</td>
#       <td id="T_dcdc0_row5_col4" class="data row5 col4" >0.7030</td>
#       <td id="T_dcdc0_row5_col5" class="data row5 col5" >0.3875</td>
#       <td id="T_dcdc0_row5_col6" class="data row5 col6" >0.3883</td>
#     </tr>
#     <tr>
#       <th id="T_dcdc0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dcdc0_row6_col0" class="data row6 col0" >0.7375</td>
#       <td id="T_dcdc0_row6_col1" class="data row6 col1" >0.8252</td>
#       <td id="T_dcdc0_row6_col2" class="data row6 col2" >0.6500</td>
#       <td id="T_dcdc0_row6_col3" class="data row6 col3" >0.7879</td>
#       <td id="T_dcdc0_row6_col4" class="data row6 col4" >0.7123</td>
#       <td id="T_dcdc0_row6_col5" class="data row6 col5" >0.4750</td>
#       <td id="T_dcdc0_row6_col6" class="data row6 col6" >0.4824</td>
#     </tr>
#     <tr>
#       <th id="T_dcdc0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dcdc0_row7_col0" class="data row7 col0" >0.6938</td>
#       <td id="T_dcdc0_row7_col1" class="data row7 col1" >0.7537</td>
#       <td id="T_dcdc0_row7_col2" class="data row7 col2" >0.6875</td>
#       <td id="T_dcdc0_row7_col3" class="data row7 col3" >0.6962</td>
#       <td id="T_dcdc0_row7_col4" class="data row7 col4" >0.6918</td>
#       <td id="T_dcdc0_row7_col5" class="data row7 col5" >0.3875</td>
#       <td id="T_dcdc0_row7_col6" class="data row7 col6" >0.3875</td>
#     </tr>
#     <tr>
#       <th id="T_dcdc0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dcdc0_row8_col0" class="data row8 col0" >0.7625</td>
#       <td id="T_dcdc0_row8_col1" class="data row8 col1" >0.8029</td>
#       <td id="T_dcdc0_row8_col2" class="data row8 col2" >0.7375</td>
#       <td id="T_dcdc0_row8_col3" class="data row8 col3" >0.7763</td>
#       <td id="T_dcdc0_row8_col4" class="data row8 col4" >0.7564</td>
#       <td id="T_dcdc0_row8_col5" class="data row8 col5" >0.5250</td>
#       <td id="T_dcdc0_row8_col6" class="data row8 col6" >0.5257</td>
#     </tr>
#     <tr>
#       <th id="T_dcdc0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dcdc0_row9_col0" class="data row9 col0" >0.7250</td>
#       <td id="T_dcdc0_row9_col1" class="data row9 col1" >0.7581</td>
#       <td id="T_dcdc0_row9_col2" class="data row9 col2" >0.7125</td>
#       <td id="T_dcdc0_row9_col3" class="data row9 col3" >0.7308</td>
#       <td id="T_dcdc0_row9_col4" class="data row9 col4" >0.7215</td>
#       <td id="T_dcdc0_row9_col5" class="data row9 col5" >0.4500</td>
#       <td id="T_dcdc0_row9_col6" class="data row9 col6" >0.4501</td>
#     </tr>
#     <tr>
#       <th id="T_dcdc0_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_dcdc0_row10_col0" class="data row10 col0" >0.7156</td>
#       <td id="T_dcdc0_row10_col1" class="data row10 col1" >0.7722</td>
#       <td id="T_dcdc0_row10_col2" class="data row10 col2" >0.7025</td>
#       <td id="T_dcdc0_row10_col3" class="data row10 col3" >0.7229</td>
#       <td id="T_dcdc0_row10_col4" class="data row10 col4" >0.7112</td>
#       <td id="T_dcdc0_row10_col5" class="data row10 col5" >0.4312</td>
#       <td id="T_dcdc0_row10_col6" class="data row10 col6" >0.4330</td>
#     </tr>
#     <tr>
#       <th id="T_dcdc0_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_dcdc0_row11_col0" class="data row11 col0" >0.0284</td>
#       <td id="T_dcdc0_row11_col1" class="data row11 col1" >0.0360</td>
#       <td id="T_dcdc0_row11_col2" class="data row11 col2" >0.0527</td>
#       <td id="T_dcdc0_row11_col3" class="data row11 col3" >0.0348</td>
#       <td id="T_dcdc0_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %% [markdown]
# We can also see the exact parameters that were chosing during the model tuning by running the cell below:

# %%
best_model_tuned.get_params()
# Out:
# {'algorithm': 'SAMME',
#  'estimator': None,
#  'learning_rate': 0.1,
#  'n_estimators': 120,
#  'random_state': 0}

# %% [markdown]
# <details>
# <summary><i>Answer:</i></summary>
#
# Each fold is a specific split of our data.
#
# If we look at the 'mean' row, the overall performance is not really better. So it seems like tuning our model didn't improve our scores of the default values!
# </details>
# <br>

# %% [markdown]
# h) We might also want to know exactly which features were most important to our model out of the data that was fed in.
#
# To create the features importance graph, call the function `plot_model()` with the model of your choice and add the argument plot="feature".
#
# How do you interpret these values?

# %%
plot_model(best_model, plot='feature')
