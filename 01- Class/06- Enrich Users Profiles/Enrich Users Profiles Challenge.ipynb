# %% [markdown]
#  ![Emil](data:image/png;base64,...)

# %% [markdown]
# # Enrich users profiles

# %% [markdown]
# In this challenge, you will explore a dataset of companies and extract companies information from it!

# %% [markdown]
# ## General data exploration

# %% [markdown]
# Import the [`microsoft_companies.json`](https://drive.google.com/file/d/11OEnC2WS74hv7MdTlOcSeK0UL1KYBXGp/view?usp=sharing) file into Colab.
#
# Run the code below to get the results in the `microsoft_companies` variable. We will study on Day 3 how to load data in Python.

# %%
import json

with open('microsoft_companies.json') as json_file:
    microsoft_companies = json.load(json_file)

# %% [markdown]
# What is the type of the `microsoft_companies` variable?

# %%
#your code here
type(microsoft_companies)
# Out:
# list

# %% [markdown]
# How many companies are in this list?

# %%
#your code here
len(microsoft_companies)
# Out:
# 301

# %% [markdown]
# ## Specific data exploration

# %% [markdown]
# Look at the first item on this list. What type is it?

# %%
#your code here
microsoft_companies[0]
# Out:
# {'datasetid': 'companies-on-linkedin',
#  'recordid': 'c4d310fc0f0f277e574e20f5e2185d4765a1ab3f',
#  'fields': {'total_employee_estimate': 44,
#   'size_range': '11 - 50',
#   'industry': 'computer games',
#   'linkedin_url': 'https://www.linkedin.com/company/develop-magazine',
#   'domain0': 'https://www.develop-online.net',
#   'current_employee_estimate': 6,
#   'name': 'microsoft'},
#  'record_timestamp': '2019-06-03T09:35:00+02:00'}

# %%
#your code here
type(microsoft_companies[0])
# Out:
# dict

# %% [markdown]
# For this first item, display the company name, industry, domain and total number of employees.

# %%
#your code here
dt_list = ['name', 'industry', 'domain0', 'total_employee_estimate']

for d in dt_list:
    print(microsoft_companies[0]['fields'][d])
# Out:
# microsoft
# computer games
# https://www.develop-online.net
# 44

# %% [markdown]
# Do you think that this company named "microsoft" is the giant American company?

# %% [markdown]
# - **Nopes**

# %% [markdown]
# Obviously not ! It seems there are homonyms in our list.
#
# Create a new empty list and add all the companies whose names are exactly "microsoft".
#
# To do this, you will need to loop through all the companies and use a condition to check that their names are indeed "microsoft". If this is the case, the company information will be added to the empty list.
#
# How many are there?

# %%
exact_microsoft_companies = [x for x in microsoft_companies if x['fields']['name'] == 'microsoft']

print(len(exact_microsoft_companies))
# Out:
# 6

# %% [markdown]
# Among the results obtained, do you see the giant American company?
#
# You can run the code below and then use the `pprint` function to indent the results. It works like the `print` function with improved readability.

# %%
from pprint import pprint
pprint(exact_microsoft_companies)
# Out:
# [{'datasetid': 'companies-on-linkedin',
#   'fields': {'current_employee_estimate': 6,
#              'domain0': 'https://www.develop-online.net',
#              'industry': 'computer games',
#              'linkedin_url': 'https://www.linkedin.com/company/develop-magazine',
#              'name': 'microsoft',
#              'size_range': '11 - 50',
#              'total_employee_estimate': 44},
#   'record_timestamp': '2019-06-03T09:35:00+02:00',
#   'recordid': 'c4d310fc0f0f277e574e20f5e2185d4765a1ab3f'},
#  {'datasetid': 'companies-on-linkedin',
#   'fields': {'country': 'united states',
#              'current_employee_estimate': 116196,
#              'domain0': 'https://www.microsoft.com',
#              'industry': 'computer software',
#              'linkedin_url': 'https://www.linkedin.com/company/microsoft',
#              'locality': 'redmond,washington,united states',
#              'name': 'microsoft',
#              'size_range': '10001+',
#              'total_employee_estimate': 276983,
#              'year_founded': '1975'},
#   'record_timestamp': '2019-06-03T09:35:00+02:00',
#   'recordid': 'd8611a51def434f1049b899a99d8a589fbb7b9c1'},
#  {'datasetid': 'companies-on-linkedin',
#   'fields': {'current_employee_estimate': 1,
#              'domain0': 'https://www.',
#              'industry': 'computer software',
#              'linkedin_url': 'https://www.linkedin.com/company/microsoft-cyprus',
#              'name': 'microsoft',
#              'size_range': '1 - 10',
#              'total_employee_estimate': 5,
#              'year_founded': '1975'},
#   'record_timestamp': '2019-06-03T09:35:00+02:00',
#   'recordid': 'a5140838fb9ffcda43fa4b8f35cd13ed2abe67f7'},
#  {'datasetid': 'companies-on-linkedin',
#   'fields': {'current_employee_estimate': 6,
#              'domain0': 'https://www.',
#              'industry': 'computer software',
#              'linkedin_url': 'https://www.linkedin.com/company/microsoft-2',
#              'name': 'microsoft',
#              'size_range': '11 - 50',
#              'total_employee_estimate': 9},
#   'record_timestamp': '2019-06-03T09:35:00+02:00',
#   'recordid': 'be50e923df54801d559eb644eac1580f92052573'},
#  {'datasetid': 'companies-on-linkedin',
#   'fields': {'current_employee_estimate': 0,
#              'domain0': 'https://www.microsoftaaas.com',
#              'industry': 'management consulting',
#              'linkedin_url': 'https://www.linkedin.com/company/microsoft-alliance-as-a-service',
#              'name': 'microsoft',
#              'size_range': '1 - 10',
#              'total_employee_estimate': 3,
#              'year_founded': '2012'},
#   'record_timestamp': '2019-06-03T09:35:00+02:00',
#   'recordid': '998d5e4e4bebfdb1a2af75f3b3014ddb1377c736'},
#  {'datasetid': 'companies-on-linkedin',
#   'fields': {'country': 'india',
#              'current_employee_estimate': 1,
#              'domain0': 'https://www.maziksolutions.com',
#              'industry': 'information technology and services',
#              'linkedin_url': 'https://www.linkedin.com/company/mazik-solutions-pvt-ltd',
#              'name': 'microsoft',
#              'size_range': '1 - 10',
#              'total_employee_estimate': 4,
#              'year_founded': '2010'},
#   'record_timestamp': '2019-06-03T09:35:00+02:00',
#   'recordid': '694e5569ffadbee848f1c3ab7a180f158a5506be'}]

# %% [markdown]
# - Yeap. I the one with the domain: 'https://www.microsoft.com'

# %% [markdown]
# ## Cleaning the data

# %% [markdown]
# ### Encoding categories

# %% [markdown]
# To facilitate the work of the other teams, we will translate the number of employees into categories. To do this, we will use the following correspondences:
#    - less than 5: "small business"
#    - from 5 to 30: "startup"
#    - from 30 to 200: "scaleup"
#    - from 200 to 1000: "big companies"
#    - more than 1000: "very large companies"
#
#
# Write a function that takes one argument, the number of employees, and returns the corresponding category.
#
# ⚠️ Don't forget to return the corresponding category at the end of your function using the **return** keyword. \
# Look carefully at the syntax of functions in the lecture.

# %%
def from_nb_employee_to_category(total_employee):

    company_size = ''

    if total_employee < 5:
        company_size = 'small business'
    elif total_employee >= 5 and total_employee < 30:
        company_size = 'startup'    
    elif total_employee >= 5 and total_employee < 30:
        company_size = 'scaleup'   
    elif total_employee >= 5 and total_employee < 30:
        company_size = 'big companies"' 
    elif total_employee > 1000:
        company_size = 'very large companies'     

    return company_size



print(from_nb_employee_to_category(23))
# Out:
# startup

# %% [markdown]
# ### Transform the data

# %% [markdown]
# We will go through all the companies in the initial file.
#
# We will create an empty list that will record all the information about each company as we go along.
#
# For each company, store in a **dictionary** the company's name, industry, domain and company category (in relation to its number of employees, using your previous function). Then add this dictionary to your list.
#
# In the end, your list will contain all the dictionaries of all the companies.

# %%
microsoft_companies_clean = []

# dt_list = ['name', 'industry', 'domain0', 'total_employee_estimate']

for i in range(len(microsoft_companies)):
    dict = {}
    for dt in dt_list:
        dict[dt] =  microsoft_companies[i]['fields'][dt]
    microsoft_companies_clean.append(dict)

# %%
microsoft_companies_clean
# Out:
# [{'name': 'microsoft',
#   'industry': 'computer games',
#   'domain0': 'https://www.develop-online.net',
#   'total_employee_estimate': 44},
#  {'name': 'omaha microsoft technology group',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.omahamtg.com',
#   'total_employee_estimate': 2},
#  {'name': 'microsoft alumni network ambassadors',
#   'industry': 'non-profit organization management',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 3},
#  {'name': 'scbn | microsoft certified professional - google partner',
#   'industry': 'internet',
#   'domain0': 'https://www.scbn.biz',
#   'total_employee_estimate': 7},
#  {'name': 'locatelli mcc - designing domotica (voip) solutions combined with microsoft lync services!',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.locatelli-mcc.com',
#   'total_employee_estimate': 4},
#  {'name': 'chelford solutions for microsoft',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 10},
#  {'name': 'troy consulting / microsoft',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 3},
#  {'name': 'microsoft pakistan',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 3},
#  {'name': 'server and management studios (sams) formerly max at microsoft',
#   'industry': 'online media',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 2},
#  {'name': 'global project pros (microsoft partner, ibm business partner)',
#   'industry': 'logistics and supply chain',
#   'domain0': 'https://www.domis.rs',
#   'total_employee_estimate': 5},
#  {'name': 'microsoft(po from hirepro consulting pvt. ltd.)',
#   'industry': 'staffing and recruiting',
#   'domain0': 'https://www.hirepro.us',
#   'total_employee_estimate': 4},
#  {'name': 'microsoft advanced analytics',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 47},
#  {'name': 'microsoft innovation center campinas',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'microsoft users group argentina',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.mug.org.ar',
#   'total_employee_estimate': 11},
#  {'name': 'mbs-training - microsoft dynamics readiness center',
#   'industry': 'professional training & coaching',
#   'domain0': 'https://www.learn4nav.com',
#   'total_employee_estimate': 3},
#  {'name': 'pohn it-consulting gmbh',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 5},
#  {'name': 'informo tecnologia microsoft partner',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.informo.com.br',
#   'total_employee_estimate': 9},
#  {'name': 'microsoft',
#   'industry': 'computer software',
#   'domain0': 'https://www.microsoft.com',
#   'total_employee_estimate': 276983},
#  {'name': 'microsoft business user forum e.v.',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 4},
#  {'name': 'your brand in microsoft office',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.ybimo.com',
#   'total_employee_estimate': 2},
#  {'name': 'microsoft innovation center - productivity',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.productivitycenter.org',
#   'total_employee_estimate': 8},
#  {'name': 'forum du laboratoire supinfo des technologies microsoft',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.forum-microsoft.org',
#   'total_employee_estimate': 10},
#  {'name': 'microsoft  technology sa',
#   'industry': 'accounting',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 10},
#  {'name': 'microsoft accelerator',
#   'industry': 'computer software',
#   'domain0': 'https://www.microsoftaccelerator.com',
#   'total_employee_estimate': 67},
#  {'name': 'microsoft slovenija',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.microsoft.si',
#   'total_employee_estimate': 22},
#  {'name': 'microsoft ireland',
#   'industry': 'writing and editing',
#   'domain0': 'https://www.googlie.ie',
#   'total_employee_estimate': 3},
#  {'name': 'microsoft office 365 sign in',
#   'industry': 'computer software',
#   'domain0': 'https://www.microsoftoffice365signin.com',
#   'total_employee_estimate': 1},
#  {'name': 'skill enhanced academic solution pvt ltd-microsoft aep',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.seasolution.in',
#   'total_employee_estimate': 2},
#  {'name': 'technokids inc. | publisher of microsoft office and google apps technology projects',
#   'industry': 'publishing',
#   'domain0': 'https://www.technokids.com',
#   'total_employee_estimate': 82},
#  {'name': 'microsoft schweiz gmbh',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 10},
#  {'name': 'excel and access, llc - local microsoft excel and access services for business 844-ms-excel',
#   'industry': 'computer software',
#   'domain0': 'https://www.excelandaccess.com',
#   'total_employee_estimate': 16},
#  {'name': 'denver area microsoft access users group',
#   'industry': 'computer software',
#   'domain0': 'https://www.daaug.org',
#   'total_employee_estimate': 1},
#  {'name': 'microsoft solutions',
#   'industry': 'computer software',
#   'domain0': 'https://www.avnetmssolutions.com',
#   'total_employee_estimate': 3},
#  {'name': 'microsoft student technical community — vit vellore',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 2},
#  {'name': 'microsoft partner',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 19},
#  {'name': 'microsoft mobile',
#   'industry': 'international trade and development',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 14},
#  {'name': 'microsoft student partners tech club - bue',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 5},
#  {'name': 'microsoft nl students',
#   'industry': 'higher education',
#   'domain0': 'https://www.dreamspark.com',
#   'total_employee_estimate': 1},
#  {'name': 'communication square llc - microsoft gold partner',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.communicationsquare.com',
#   'total_employee_estimate': 11},
#  {'name': 'microsoft student partners upb',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 14},
#  {'name': 'microsoft innovation center armenia',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.mic.am',
#   'total_employee_estimate': 27},
#  {'name': 'microsoft oy',
#   'industry': 'electrical/electronic manufacturing',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 5},
#  {'name': 'microsoft tech-club at bue',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 7},
#  {'name': 'makay services',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'microsoft deutschland gmbh',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 10},
#  {'name': 'microsoft software belgrade',
#   'industry': 'information services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 5},
#  {'name': 'microsoft corporation (i) pvt. ltd.',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 4},
#  {'name': 'clickstream technologies (acquired by microsoft)',
#   'industry': 'computer software',
#   'domain0': 'https://www.clickstreamtech.com',
#   'total_employee_estimate': 7},
#  {'name': 'microsoft campus club',
#   'industry': 'computer software',
#   'domain0': 'https://www.microsoftcampusclub.in',
#   'total_employee_estimate': 35},
#  {'name': 'the microsoft research - university of trento centre for computational and systems biology',
#   'industry': 'research',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 21},
#  {'name': 'microsoft nepal',
#   'industry': 'computer & network security',
#   'domain0': 'https://www.microsoftstudentpartners.com',
#   'total_employee_estimate': 12},
#  {'name': 'microsoft innovation center são josé dos campos',
#   'industry': 'research',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 3},
#  {'name': 'microsoft licensing, gp',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 7},
#  {'name': 'kvk, microsoft, american express',
#   'industry': 'unknown',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'microsoft consultancy az',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.zoutenbier.nl',
#   'total_employee_estimate': 1},
#  {'name': 'microsoft it academy at touro college israel',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.missupport.com',
#   'total_employee_estimate': 17},
#  {'name': 'vital partners, llc a microsoft gold certified partner',
#   'industry': 'computer software',
#   'domain0': 'https://www.vitalpartners.net',
#   'total_employee_estimate': 3},
#  {'name': 'microsoft windays konferencija',
#   'industry': 'computer software',
#   'domain0': 'https://www.windays.hr',
#   'total_employee_estimate': 2},
#  {'name': 'mbo - partner especialistas en microsoft dynamics 365',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.mbolatam.cl',
#   'total_employee_estimate': 3},
#  {'name': 'htd training (microsoft gold certified)',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.blueworkershtd.co.uk',
#   'total_employee_estimate': 1},
#  {'name': 'capptain, une entreprise microsoft',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 15},
#  {'name': 'microsoft technet social forums',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 2},
#  {'name': 'microsoft student partners tech club',
#   'industry': 'computer software',
#   'domain0': 'https://www.buetc.com',
#   'total_employee_estimate': 12},
#  {'name': 'sheath | microsoft csp and saas company',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.sheathtechnologysolutions.com',
#   'total_employee_estimate': 1},
#  {'name': 'sirrus',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'mos champions consulting - microsoft partner',
#   'industry': 'education management',
#   'domain0': 'https://www.moschampions.com',
#   'total_employee_estimate': 2},
#  {'name': 'microsoft certifications',
#   'industry': 'unknown',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'iamcp',
#   'industry': 'unknown',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'microsoft certified trainer/consultant/mentor',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 2},
#  {'name': 'microsoft taiwan 台灣微軟',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 4},
#  {'name': 'microsoft zune',
#   'industry': 'entertainment',
#   'domain0': 'https://www.zune.net',
#   'total_employee_estimate': 27},
#  {'name': "ag consultancy, specialists in sap, winshuttle and microsoft integration (inc' excel macro)",
#   'industry': 'information technology and services',
#   'domain0': 'https://www.agcapps.com',
#   'total_employee_estimate': 23},
#  {'name': 'calgary microsoft user group',
#   'industry': 'consumer services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'hungarian user group of microsoft sql server',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.hug-mssql.hu',
#   'total_employee_estimate': 2},
#  {'name': 'naax - microsoft dynamics',
#   'industry': 'staffing and recruiting',
#   'domain0': 'https://www.naax.dk',
#   'total_employee_estimate': 1},
#  {'name': 'cbre | microsoft',
#   'industry': 'information services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 16},
#  {'name': 'microsoft accelerator tel aviv',
#   'industry': 'internet',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 3},
#  {'name': 'i4ict - apple, microsoft & google apps specialist',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.i4ict.com',
#   'total_employee_estimate': 2},
#  {'name': 'microsoft xbox support',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 6},
#  {'name': 'dotwood crm - your microsoft cloud partner',
#   'industry': 'computer software',
#   'domain0': 'https://www.dotwoodcrm.nl',
#   'total_employee_estimate': 17},
#  {'name': 'microsoft original products in iran - لایسنس اصلی محصولات مایکروسافت',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 7},
#  {'name': 'microsoft partner development centre asia pacific',
#   'industry': 'professional training & coaching',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 7},
#  {'name': 'microsoft certified professional magazine',
#   'industry': 'unknown',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'microsoft gold partner - veripark',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'microsoft business solution nav and ax consultant',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 10},
#  {'name': 'ciphergraph networks (microsoft accelerator)',
#   'industry': 'computer & network security',
#   'domain0': 'https://www.ciphergraph.com',
#   'total_employee_estimate': 4},
#  {'name': 'microsoft student partners russia',
#   'industry': 'unknown',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 2},
#  {'name': 'brisbane microsoft 365 meetup',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.365community.org',
#   'total_employee_estimate': 1},
#  {'name': 'eoh: a microsoft partner',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.eohamp.co.za',
#   'total_employee_estimate': 360},
#  {'name': 'bing pulse',
#   'industry': 'internet',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 4},
#  {'name': 'northern ireland microsoft technologies user group (nimtug)',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 4},
#  {'name': 'microsoft engineering limited',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 3},
#  {'name': 'mictt palma',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 3},
#  {'name': 'microsoft operations puerto rico, llc',
#   'industry': 'computer & network security',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 4},
#  {'name': 'microsoft office',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.office.com',
#   'total_employee_estimate': 1},
#  {'name': 'astoine "gold certified microsoft cloud technology" maroc',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.astoine.com',
#   'total_employee_estimate': 4},
#  {'name': 'microsoft magyarország kft.',
#   'industry': 'computer software',
#   'domain0': 'https://www.microsoft.hu',
#   'total_employee_estimate': 2},
#  {'name': 'microsoft open technologies, inc.',
#   'industry': 'unknown',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'directions on microsoft',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.directionsonmicrosoft.com',
#   'total_employee_estimate': 18},
#  {'name': 'microsoft business solutions',
#   'industry': 'unknown',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 2},
#  {'name': 'this is it | time saving and efficiency training for microsoft office',
#   'industry': 'e-learning',
#   'domain0': 'https://www.e-thisisit.com',
#   'total_employee_estimate': 6},
#  {'name': 'microsoft dynamics nav',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 15},
#  {'name': 'microsoft innovation center belo horizonte',
#   'industry': 'computer software',
#   'domain0': 'https://www.micbh.com.br',
#   'total_employee_estimate': 117},
#  {'name': 'universidade católica de petrópolis',
#   'industry': 'higher education',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 22},
#  {'name': 'microsoft innovation center yogyakarta',
#   'industry': 'research',
#   'domain0': 'https://www.micresearch.net',
#   'total_employee_estimate': 7},
#  {'name': 'microsoft india (r&d) private limited',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 5},
#  {'name': 'harwood consulting - microsoft software development',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.harwoodconsulting.com.au',
#   'total_employee_estimate': 3},
#  {'name': 'adactit | microsoft cloud partner of the year 2015 winner',
#   'industry': 'computer software',
#   'domain0': 'https://www.adactit.com',
#   'total_employee_estimate': 20},
#  {'name': 'microsoft office training',
#   'industry': 'professional training & coaching',
#   'domain0': 'https://www.audiosolutionz.com',
#   'total_employee_estimate': 80},
#  {'name': 'microsoft puerto rico inc',
#   'industry': 'public relations and communications',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'microsoft xrm consultants, llc',
#   'industry': 'computer software',
#   'domain0': 'https://www.mosaik.ch',
#   'total_employee_estimate': 6},
#  {'name': 'microsoft dynamicsnav',
#   'industry': 'management consulting',
#   'domain0': 'https://www.abadyn.es',
#   'total_employee_estimate': 5},
#  {'name': 'microsoft innovation center | kharkov, ukraine',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 3},
#  {'name': 'spilog | distribution microsoft pacifique francophone',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.spilog.pf',
#   'total_employee_estimate': 6},
#  {'name': 'trivium | microsoft partner',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.trivium.com.br',
#   'total_employee_estimate': 3},
#  {'name': 'academia microsoft, upb - itacad',
#   'industry': 'computer software',
#   'domain0': 'https://www.itacad.ro',
#   'total_employee_estimate': 8},
#  {'name': 'bluestar plm for microsoft dynamics ax',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.bluestarplm.com',
#   'total_employee_estimate': 15},
#  {'name': 'centro de innovacion en movilidad - microsoft innovation center',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.micmovilidad.es',
#   'total_employee_estimate': 8},
#  {'name': 'microsoft hrvatska',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.microsoft.hr',
#   'total_employee_estimate': 10},
#  {'name': 'microsoft ventures accelerator academy r&d hertzelia',
#   'industry': 'unknown',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'microsoft customer support',
#   'industry': 'computer software',
#   'domain0': 'https://www.supportonline.help',
#   'total_employee_estimate': 4},
#  {'name': 'microsoft cz',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 2},
#  {'name': 'microsoft financing / bnp paribas lease group',
#   'industry': 'unknown',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'mcafee antivirus technical support phone number 1-800-769-2805',
#   'industry': 'computer software',
#   'domain0': 'https://www.akgls.net',
#   'total_employee_estimate': 3},
#  {'name': 'net it - microsoft crm partner',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.net-it.be',
#   'total_employee_estimate': 45},
#  {'name': 'microsoft corporation india pvt ltd.',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 6},
#  {'name': 'text’d, llc (vendor of microsoft corporation)',
#   'industry': 'internet',
#   'domain0': 'https://www.textd.com',
#   'total_employee_estimate': 2},
#  {'name': 'kadamba software - microsoft sharepoint services',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.kadamba.com',
#   'total_employee_estimate': 19},
#  {'name': 'convergys/microsoft',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 470},
#  {'name': 'point 42 - microsoft professionals',
#   'industry': 'computer software',
#   'domain0': 'https://www.point42.nl',
#   'total_employee_estimate': 12},
#  {'name': 'microsoft licensing',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.nevadaitsolutions.com',
#   'total_employee_estimate': 143},
#  {'name': 'microsoft armenia',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 2},
#  {'name': 'microsoft france',
#   'industry': 'computer software',
#   'domain0': 'https://www.microsoft.fr',
#   'total_employee_estimate': 25},
#  {'name': 'criativa marketing and solutions (microsoft partner)',
#   'industry': 'management consulting',
#   'domain0': 'https://www.criativamarketing.com.br',
#   'total_employee_estimate': 6},
#  {'name': "sony, time inc., clorox, gap corporate, honda, nike, gnc, microsoft, hp, macy's, bloomingdale's",
#   'industry': 'photography',
#   'domain0': 'https://www.monalongstyling.com',
#   'total_employee_estimate': 59},
#  {'name': 'microsoft global services',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 2},
#  {'name': 'vidgent (microsoft)',
#   'industry': 'computer games',
#   'domain0': 'https://www.vidgent.com',
#   'total_employee_estimate': 1},
#  {'name': 'microsoft innovation center | productivity center',
#   'industry': 'business supplies and equipment',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 5},
#  {'name': 'microsoft innovation center - university of indonesia',
#   'industry': 'unknown',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'go trainers treinamentos especializados em tecnologia (adobe e microsoft)',
#   'industry': 'design',
#   'domain0': 'https://www.gotrainers.com.br',
#   'total_employee_estimate': 12},
#  {'name': 'microsoft innovation center varaždin',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.miccroatia.com',
#   'total_employee_estimate': 8},
#  {'name': 'microsoft / wonderlane',
#   'industry': 'internet',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 5},
#  {'name': 'the microsoft research university of trento centre for computational and systems biology s',
#   'industry': 'unknown',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 2},
#  {'name': 'microsoft corporation india pvt ltd.',
#   'industry': 'unknown',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 3},
#  {'name': 'mic belgique - microsoft innovation center mons',
#   'industry': 'management consulting',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 3},
#  {'name': 'microsoftware s.r.l.',
#   'industry': 'unknown',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 2},
#  {'name': 'microsoft dynamics gurus gp nav erp ax',
#   'industry': 'accounting',
#   'domain0': 'https://www.microsoftdynamicsgpgurus.com',
#   'total_employee_estimate': 2},
#  {'name': 'microsoft cloud it pro podcast',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.msclouditpropodcast.com',
#   'total_employee_estimate': 4},
#  {'name': 'jm global search - recruiting microsoft professionals',
#   'industry': 'staffing and recruiting',
#   'domain0': 'https://www.jmglobalsearch.com',
#   'total_employee_estimate': 2},
#  {'name': 'microsoft student partners uaic',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 30},
#  {'name': 'understanding microsoft',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'microsoft dynamics 365 advisors',
#   'industry': 'luxury goods & jewelry',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'solutions metrix - certified crm partner (microsoft, oracle, salesforce & sugarcrm)',
#   'industry': 'computer software',
#   'domain0': 'https://www.solutionsmetrix.com',
#   'total_employee_estimate': 43},
#  {'name': 'microsoft alumni network',
#   'industry': 'civic & social organization',
#   'domain0': 'https://www.microsoftalumni.com',
#   'total_employee_estimate': 41},
#  {'name': 'microsoft emea',
#   'industry': 'internet',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 2},
#  {'name': 'microsoft india',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 26},
#  {'name': 'microsoft research asia',
#   'industry': 'computer software',
#   'domain0': 'https://www.msra.cn',
#   'total_employee_estimate': 8},
#  {'name': 'gtplus',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 3},
#  {'name': 'microsoft dynamics gulf',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.dynamics.com',
#   'total_employee_estimate': 11},
#  {'name': 'microsoft innovation center brussels',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.mic-brussels.be',
#   'total_employee_estimate': 57},
#  {'name': 'excellence - capacitación microsoft excel',
#   'industry': 'professional training & coaching',
#   'domain0': 'https://www.cursosdexcel.com',
#   'total_employee_estimate': 1},
#  {'name': 'microsoft services(bertelsmann group)',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 2},
#  {'name': 'bluehealth innovation center-supported by microsoft',
#   'industry': 'health, wellness and fitness',
#   'domain0': 'https://www.bhic.care',
#   'total_employee_estimate': 10},
#  {'name': 'oryxdev .net ug (microsoft qatar developers club)',
#   'industry': 'non-profit organization management',
#   'domain0': 'https://www.oryxdev.net',
#   'total_employee_estimate': 2},
#  {'name': 'microsoft technical community-upes',
#   'industry': 'computer & network security',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 3},
#  {'name': 'senterprise - microsoft professionals',
#   'industry': 'staffing and recruiting',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 7},
#  {'name': 'microsoft excel training and microsoft excel vba training',
#   'industry': 'professional training & coaching',
#   'domain0': 'https://www.emagenit.com',
#   'total_employee_estimate': 4},
#  {'name': 'microsoft bpos',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 3},
#  {'name': 'microsoft dynamics ax',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.srfconsultores.com',
#   'total_employee_estimate': 56},
#  {'name': 'microsoft perú',
#   'industry': 'utilities',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 2},
#  {'name': 'training 4 microsoft crm',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.training4microsoftcrm.co.uk',
#   'total_employee_estimate': 3},
#  {'name': 'business solutions in microsoft technology',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.bsmt.uk',
#   'total_employee_estimate': 2},
#  {'name': 'mr. access | microsoft access experts',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.mraccess.nl',
#   'total_employee_estimate': 3},
#  {'name': 'microsoft powerpoint',
#   'industry': 'program development',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'malaysia microsoft project users group (mympug)',
#   'industry': 'unknown',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'nixey computer solutions ltd  - microsoft silver partner windows and devices',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.nixeysolutions.com',
#   'total_employee_estimate': 1},
#  {'name': 'cognitive group | microsoft talent solutions',
#   'industry': 'staffing and recruiting',
#   'domain0': 'https://www.cognitive-group.com',
#   'total_employee_estimate': 65},
#  {'name': 'atlanta microsoft messaging & mobility user group',
#   'industry': 'unknown',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'microsoft business center nederland',
#   'industry': 'accounting',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 3},
#  {'name': 'microsoft student partner network in bangladesh',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 15},
#  {'name': 'microsoft advanced analytics',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 168},
#  {'name': 'sun microsoft pvt. ltd.',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 13},
#  {'name': 'microsoft innovation center hainan',
#   'industry': 'unknown',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 3},
#  {'name': 'pdc australia',
#   'industry': 'unknown',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'microsoft sri lanka',
#   'industry': 'unknown',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'microsoft 365 support',
#   'industry': 'consumer services',
#   'domain0': 'https://www.microsoft-365-support.com',
#   'total_employee_estimate': 1},
#  {'name': 'integral solutions (microsoft dynamics partner), west africa',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.integral-solutions.com',
#   'total_employee_estimate': 2},
#  {'name': 'webatme - microsoft silver partner',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.webatme.com',
#   'total_employee_estimate': 7},
#  {'name': 'uk microsoft azure user group',
#   'industry': 'computer software',
#   'domain0': 'https://www.azureusergroup.com',
#   'total_employee_estimate': 1},
#  {'name': 'microsoft fasttrack',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'microsoft ireland',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 21},
#  {'name': 'phonefactor, now a microsoft company',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.phonefactor.com',
#   'total_employee_estimate': 41},
#  {'name': 'microsoft tech club - must',
#   'industry': 'non-profit organization management',
#   'domain0': 'https://www.musttc.com',
#   'total_employee_estimate': 30},
#  {'name': 'senior trainer for microsoft authorized education center',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.specialfy.com',
#   'total_employee_estimate': 3},
#  {'name': 'microsoft insider',
#   'industry': 'consumer electronics',
#   'domain0': 'https://www.microsoftinsider.es',
#   'total_employee_estimate': 9},
#  {'name': 'softimage (microsoft/avid /autodesk)',
#   'industry': 'animation',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'microsoft mvp programme',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 3},
#  {'name': 'microsoft ventures',
#   'industry': 'management consulting',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 6},
#  {'name': 'microsoft technical community lpu',
#   'industry': 'education management',
#   'domain0': 'https://www.microsoftlpu.com',
#   'total_employee_estimate': 1},
#  {'name': 'dansk microsoftware a/s',
#   'industry': 'computer software',
#   'domain0': 'https://www.danms.dk',
#   'total_employee_estimate': 3},
#  {'name': 'msp tech club - alexandria university',
#   'industry': 'computer software',
#   'domain0': 'https://www.alexutc.com',
#   'total_employee_estimate': 27},
#  {'name': 'cloud point - all we do is microsoft cloud',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.cloud-point.co.uk',
#   'total_employee_estimate': 1},
#  {'name': 'financeseer llc (microsoft partner)',
#   'industry': 'computer software',
#   'domain0': 'https://www.financeseer.com',
#   'total_employee_estimate': 3},
#  {'name': 'microsoft student partners bangladesh',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 64},
#  {'name': 'microsoft user research',
#   'industry': 'research',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 2},
#  {'name': 'global enterprise partners - experts in sap | microsoft | oracle | salesforce.com |',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 4},
#  {'name': 'global sports innovation center powered by microsoft',
#   'industry': 'sports',
#   'domain0': 'https://www.sport-gsic.com',
#   'total_employee_estimate': 5},
#  {'name': 'microsoft corporation - c2s technologies',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 2},
#  {'name': 'microsoft campus club, svvv',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'microsoft',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 5},
#  {'name': 'boston microsoft bizspark startup meetup',
#   'industry': 'internet',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 20},
#  {'name': 'mic belgique - microsoft innovation center mons',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.mic-belgique.be',
#   'total_employee_estimate': 117},
#  {'name': 'axlogic - certificeret microsoft dynamics ax partner',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.axlogic.dk',
#   'total_employee_estimate': 6},
#  {'name': 'microsoft hellas',
#   'industry': 'computer software',
#   'domain0': 'https://www.microsoft.gr',
#   'total_employee_estimate': 1},
#  {'name': 'inteleserv bpo services(a microsoft bizspark company)',
#   'industry': 'outsourcing/offshoring',
#   'domain0': 'https://www.inteleserv.com',
#   'total_employee_estimate': 4},
#  {'name': 'msbs - microsoft business solutions',
#   'industry': 'management consulting',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 77},
#  {'name': 'microsoft innovation center nepal hosted by unlimited',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.micneoal.org',
#   'total_employee_estimate': 11},
#  {'name': 'msb365 | the microsoft blog',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.msb365.blog',
#   'total_employee_estimate': 2},
#  {'name': 'dux-it',
#   'industry': 'information services',
#   'domain0': 'https://www.duxit.nl',
#   'total_employee_estimate': 1},
#  {'name': 'microsoft south africa',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.microsoft.co.za',
#   'total_employee_estimate': 16},
#  {'name': 'microsoft',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 9},
#  {'name': 'natural corporation (sap sme partner and microsoft partner)',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.nycartinstallation.com',
#   'total_employee_estimate': 1},
#  {'name': 'new horizons computer learning centers of washington d.c.',
#   'industry': 'education management',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 3},
#  {'name': 'peter moyer - microsoft certified trainer',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'soft flow (microsoft gold partner) & sap partner',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.softflow.com.lb',
#   'total_employee_estimate': 65},
#  {'name': 'microsoft tech club - cic',
#   'industry': 'non-profit organization management',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 10},
#  {'name': 'enterprise training group (the providers of microsoft training courses)',
#   'industry': 'professional training & coaching',
#   'domain0': 'https://www.enterprisetraininggroup.co.uk',
#   'total_employee_estimate': 1},
#  {'name': 'microsoft / shanghai msn network communications technology co. ltd',
#   'industry': 'unknown',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'microsoft outlook tech support telephone number',
#   'industry': 'accounting',
#   'domain0': 'https://www.supportcontactnumber.com',
#   'total_employee_estimate': 1},
#  {'name': 'msemploy - the microsoft recruitment specialists',
#   'industry': 'staffing and recruiting',
#   'domain0': 'https://www.msemploy.co.uk',
#   'total_employee_estimate': 6},
#  {'name': 'gallantcloud games (microsoft ventures accelerator london)',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.gallantcloud.com',
#   'total_employee_estimate': 2},
#  {'name': 'hcs company microsoft services',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'centro de inovaçao microsoft',
#   'industry': 'unknown',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 13},
#  {'name': 'microsoft accelerator in india',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 3},
#  {'name': 'microsoft download center',
#   'industry': 'computer software',
#   'domain0': 'https://www.softwareoptions.net',
#   'total_employee_estimate': 1},
#  {'name': 'the microsoft dynamics job center us/canada',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 15},
#  {'name': 'microsoft office 365',
#   'industry': 'computer software',
#   'domain0': 'https://www.office2010.bg',
#   'total_employee_estimate': 42},
#  {'name': 'microsoft west and central africa (wca)',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 31},
#  {'name': 'microsoft tech club - met academy',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 7},
#  {'name': 'microsoft innovation center rapperswil',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.msic.ch',
#   'total_employee_estimate': 4},
#  {'name': 'microsoft innovation center',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 8},
#  {'name': 'javista, microsoft dynamics crm and social crm solutions',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.javista.com',
#   'total_employee_estimate': 74},
#  {'name': 'microsoft persia',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'silverware, inc. (microsoft dynamics erp var and intacct cloud financials var)',
#   'industry': 'computer software',
#   'domain0': 'https://www.silverw.com',
#   'total_employee_estimate': 30},
#  {'name': 'lgroup desenvolvimento e treinamento em tecnologia microsoft',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 16},
#  {'name': 'global enterprise partners - experts in sap | microsoft | oracle | salesforce.com |',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.globalenterprisepartners.com',
#   'total_employee_estimate': 37},
#  {'name': 'microsoft korea',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 80},
#  {'name': 'microsoft dynamics ax brains',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 6},
#  {'name': 'd4bsolutions - expertos en microsoft dynamics nav',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.d4bsolutions.com',
#   'total_employee_estimate': 7},
#  {'name': 'microsoft dynamics farsi',
#   'industry': 'industrial automation',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'microsoft',
#   'industry': 'management consulting',
#   'domain0': 'https://www.microsoftaaas.com',
#   'total_employee_estimate': 3},
#  {'name': 'microsoft inc',
#   'industry': 'management consulting',
#   'domain0': 'https://www.mbunicapital.com',
#   'total_employee_estimate': 1},
#  {'name': 'cpm india',
#   'industry': 'marketing and advertising',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 10},
#  {'name': 'microsoft azure partners in cee',
#   'industry': 'computer software',
#   'domain0': 'https://www.opennessatcee.com',
#   'total_employee_estimate': 1},
#  {'name': 'snapnet nigeria tier 1 microsoft cloud service provider',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.snapnet.com.ng',
#   'total_employee_estimate': 11},
#  {'name': 'microsoft student chapter',
#   'industry': 'education management',
#   'domain0': 'https://www.msctiet.co.in',
#   'total_employee_estimate': 5},
#  {'name': 'microsoft scaleup tel aviv',
#   'industry': 'marketing and advertising',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'chengdu microsoft technology center',
#   'industry': 'computer software',
#   'domain0': 'https://www.claudiofotografias.com.br',
#   'total_employee_estimate': 24},
#  {'name': 'microsoft germany',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 84},
#  {'name': '1to1 (partner microsoft)',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.corp1to1.com',
#   'total_employee_estimate': 131},
#  {'name': 'microsoft great plains bus',
#   'industry': 'unknown',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'microsoft hong kong limited',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 6},
#  {'name': 'ms office certified and corporate trainer',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'clas healthcare - microsoft health innovation lab',
#   'industry': 'hospital & health care',
#   'domain0': 'https://www.bacsi24x7.vn',
#   'total_employee_estimate': 3},
#  {'name': 'ajp informatique & documents i concessionnaire xerox platinium i microsoft partner',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.ajp.fr',
#   'total_employee_estimate': 46},
#  {'name': 'longi engineering, p.c. (microsoft gold certified partner)',
#   'industry': 'computer & network security',
#   'domain0': 'https://www.longieng.com',
#   'total_employee_estimate': 11},
#  {'name': 'microsoft regional sales corporation',
#   'industry': 'consumer services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 3},
#  {'name': 'experts live europe | microsoft community it conference',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.expertslive.eu',
#   'total_employee_estimate': 2},
#  {'name': 'microsoft  azure store',
#   'industry': 'computer software',
#   'domain0': 'https://www.azurestore.ma',
#   'total_employee_estimate': 1},
#  {'name': 'microsofttechclub @bitspilanidubai',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 3},
#  {'name': 'microsoft iceland',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 3},
#  {'name': 'senterprise - microsoft professionals',
#   'industry': 'staffing and recruiting',
#   'domain0': 'https://www.senterprise.se',
#   'total_employee_estimate': 5},
#  {'name': 'mstc indore',
#   'industry': 'computer software',
#   'domain0': 'https://www.mstcindore.org',
#   'total_employee_estimate': 1},
#  {'name': 'metricshub, inc. (acquired by microsoft)',
#   'industry': 'computer software',
#   'domain0': 'https://www.metricshub.com',
#   'total_employee_estimate': 5},
#  {'name': 'microsoft for startups',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'microsoft cloud show',
#   'industry': 'internet',
#   'domain0': 'https://www.microsoftcloudshow.com',
#   'total_employee_estimate': 1},
#  {'name': 'microsoft dynamics nav/crm/ax/gp training course online',
#   'industry': 'education management',
#   'domain0': 'https://www.saicaregroup.in',
#   'total_employee_estimate': 2},
#  {'name': 'dcr associates - microsoft it consultancy',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.dcrassociates.com',
#   'total_employee_estimate': 2},
#  {'name': 'microsoft customer support',
#   'industry': 'consumer services',
#   'domain0': 'https://www.microsoft-customersupport.com',
#   'total_employee_estimate': 3},
#  {'name': 'microsoft nederland',
#   'industry': 'computer software',
#   'domain0': 'https://www.microsoft.nl',
#   'total_employee_estimate': 55},
#  {'name': 'the word guru - microsoft office templates & document formatting',
#   'industry': 'graphic design',
#   'domain0': 'https://www.thewordguru.com.au',
#   'total_employee_estimate': 5},
#  {'name': 'microsoft sp. z o.o.',
#   'industry': 'automotive',
#   'domain0': 'https://www.rs-academy.com',
#   'total_employee_estimate': 4},
#  {'name': 'iview (subsidiary of microsoft)',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'pettis eng recruitment  llc - microsoft',
#   'industry': 'staffing and recruiting',
#   'domain0': 'https://www.pettisengrecruit.com',
#   'total_employee_estimate': 2},
#  {'name': 'grupo ign - microsoft dynamics nav & qlikview',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.ignsl.es',
#   'total_employee_estimate': 2},
#  {'name': 'lmc consulting group - microsoft global security',
#   'industry': 'security and investigations',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 61},
#  {'name': 'techbiz learning center for ibm and microsoft technologies',
#   'industry': 'higher education',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 3},
#  {'name': 'mcl it solutions | it-systems & consulting company | microsoft gold certified partner',
#   'industry': 'unknown',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'organization dynamics, inc.- microsoft office training',
#   'industry': 'professional training & coaching',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 2},
#  {'name': 'microsoft korea, inc.',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 7},
#  {'name': 'microsoft dynamics',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'microsoft denmark',
#   'industry': 'hospitality',
#   'domain0': 'https://www.asian-connections.net',
#   'total_employee_estimate': 2},
#  {'name': 'microsoft',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.maziksolutions.com',
#   'total_employee_estimate': 4},
#  {'name': 'elitesoft group - leaders in microsoft staffing',
#   'industry': 'staffing and recruiting',
#   'domain0': 'https://www.elitesoft-group.com',
#   'total_employee_estimate': 12},
#  {'name': 'eoh mc solutions',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.eohmc.co.za',
#   'total_employee_estimate': 11},
#  {'name': 'microsoft professional services',
#   'industry': 'management consulting',
#   'domain0': 'https://www.efficaceconsultinggroup.com',
#   'total_employee_estimate': 8},
#  {'name': 'pmx dynamics-business software for the real estate industry powered by microsoft dynamics nav',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.pmxdynamics.com',
#   'total_employee_estimate': 6},
#  {'name': 'microsoft game studios',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 12},
#  {'name': 'microsoft alumni foundation',
#   'industry': 'philanthropy',
#   'domain0': 'https://www.microsoftalumni.org',
#   'total_employee_estimate': 8},
#  {'name': 'naveksa a/s - manufacturing solutions for microsoft dynamics nav',
#   'industry': 'computer software',
#   'domain0': 'https://www.',
#   'total_employee_estimate': 1},
#  {'name': 'f-keys ltd microsoft training centre',
#   'industry': 'information technology and services',
#   'domain0': 'https://www.f-keys.co.uk',
#   'total_employee_estimate': 6}]

# %% [markdown]
# Use the code below to create a `DataFrame` from it. We will learn more about this Python object in future lectures.

# %%
import pandas as pd

df_microsoft_companies_clean = pd.DataFrame(microsoft_companies_clean)
df_microsoft_companies_clean
# Out:
#                                                   name  \
# 0                                            microsoft
# 1                     omaha microsoft technology group
# 2                 microsoft alumni network ambassadors
# 3    scbn | microsoft certified professional - goog...
# 4    locatelli mcc - designing domotica (voip) solu...
# ..                                                 ...
# 296  pmx dynamics-business software for the real es...
# 297                             microsoft game studios
# 298                        microsoft alumni foundation
# 299  naveksa a/s - manufacturing solutions for micr...
# 300               f-keys ltd microsoft training centre
#
#                                 industry                          domain0  \
# 0                         computer games   https://www.develop-online.net
# 1    information technology and services         https://www.omahamtg.com
# 2     non-profit organization management                     https://www.
# 3                               internet             https://www.scbn.biz
# 4    information technology and services    https://www.locatelli-mcc.com
# ..                                   ...                              ...
# 296  information technology and services      https://www.pmxdynamics.com
# 297                    computer software                     https://www.
# 298                         philanthropy  https://www.microsoftalumni.org
# 299                    computer software                     https://www.
# 300  information technology and services         https://www.f-keys.co.uk
#
#      total_employee_estimate
# 0                         44
# 1                          2
# 2                          3
# 3                          7
# 4                          4
# ..                       ...
# 296                        6
# 297                       12
# 298                        8
# 299                        1
# 300                        6
#
# [301 rows x 4 columns]

# %% [markdown]
# Congratulations, you just created your first DataFrame! 🚀

# %% [markdown]
# ### More accurate cleaning

# %% [markdown]
# What do you notice about `domains` column ?
#
# When no domain has been found, the API outputs "https://www.".
#
# This piece of information is not relevant to other teams. Modify your code to delete that.
#
#
# <details>
#     <summary>Hint 🔍</summary>
# One way to do so is to not store this key/value pair when iterating over all companies.
# </details>

# %%
#your code here
df_microsoft_companies_clean =  df_microsoft_companies_clean.map(lambda x: x.replace('https://www.','') if x == 'https://www.' else x)

# %%
df_microsoft_companies_clean
# Out:
#                                                   name  \
# 0                                            microsoft
# 1                     omaha microsoft technology group
# 2                 microsoft alumni network ambassadors
# 3    scbn | microsoft certified professional - goog...
# 4    locatelli mcc - designing domotica (voip) solu...
# ..                                                 ...
# 296  pmx dynamics-business software for the real es...
# 297                             microsoft game studios
# 298                        microsoft alumni foundation
# 299  naveksa a/s - manufacturing solutions for micr...
# 300               f-keys ltd microsoft training centre
#
#                                 industry                          domain0  \
# 0                         computer games   https://www.develop-online.net
# 1    information technology and services         https://www.omahamtg.com
# 2     non-profit organization management
# 3                               internet             https://www.scbn.biz
# 4    information technology and services    https://www.locatelli-mcc.com
# ..                                   ...                              ...
# 296  information technology and services      https://www.pmxdynamics.com
# 297                    computer software
# 298                         philanthropy  https://www.microsoftalumni.org
# 299                    computer software
# 300  information technology and services         https://www.f-keys.co.uk
#
#      total_employee_estimate
# 0                         44
# 1                          2
# 2                          3
# 3                          7
# 4                          4
# ..                       ...
# 296                        6
# 297                       12
# 298                        8
# 299                        1
# 300                        6
#
# [301 rows x 4 columns]

# %% [markdown]
# Run the code below to export the clean dataframe to a CSV. We will learn more about the `to_csv()`function in future lectures.

# %%
df_microsoft_companies_clean.to_csv("microsoft_companies.csv",index=False)
