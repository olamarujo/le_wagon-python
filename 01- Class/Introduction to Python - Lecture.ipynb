# %% [markdown]
#  ![Emil](data:image/png;base64,...)

# %% [markdown]
# # Introduction to Python

# %% [markdown]
# Values, Variables and types

# %% [markdown]
# ### How to display a result ?

# %% [markdown]
# The `print()` function allows you to see the results displayed. But as we are in a Jupyter Notebook, this is the normal behaviour after execution of a block of code. If your block of code is to return a result, it will automatically be shown after, print is then optional. Note that if the block in question returns nothing, nothing will be displayed.

# %%
print(3)
# Out:
# 3

# %%
3
# Out:
# 3

# %% [markdown]
# Reading becomes difficult, you need to save the intermediate results! How to do it? --> Use variables

# %% [markdown]
# ### Variables

# %% [markdown]
# A variable is like a box : you put something in it, you put a label on the box. You can then transport it from one house to the other.
#
# Let's imagine, I want to put a 3 in a variable named a. This is how I should do it :

# %%
a = 3

# %% [markdown]
# This is called assignment. I assigned the value 3 to the variable a. I can then call a and the notebook will show me what is inside of it.

# %%
a
# Out:
# 3

# %% [markdown]
# One can create multiple variables in a notebook and reuse them as much as wanted. For example :

# %%
a = 3 + 4
b = 12 / a
c = 16 + 12 * b
print(c)
# Out:
# 36.57142857142857

# %% [markdown]
# We have used here 3 variables `a`, `b`, `c`
#
# Variables' names are a string, which cannot start with a number and cannot have a space!
#
# Furthermore, the `=` sign does not test for equality but is an affectation. The instruction `a = 3 + 4` tells the computer to put the value 7 in the variable `a`.

# %% [markdown]
# You can also "overwrite" the value of a variable with another value. The following instructions calculate the same result but using only one variable!

# %%
a = 3 + 4
a = 12 / a
a = 16 + 12 * a
print(a)
# Out:
# 36.57142857142857

# %% [markdown]
# The "#" symbol represents a comment and is not executed.

# %%
print(a) # I can write what I want, it's just to explain a line of code
# Out:
# 36.57142857142857

# %% [markdown]
# Comments are useful for several reasons :
#
#
# *   it gives context to your code
# *   you can remember later whant you meant to do
# *   it makes it more readable for someone else in you team

# %% [markdown]
# ### Types

# %% [markdown]
# Each variable, being a value, can be of several different types in Python.
#
# The `type()` function returns the type of the variable or value passed in brackets:

# %%
print(type(1)) # int for integer

print(type(-1.0)) # float

print(type("hello world!")) # str for string
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# What would be the result for our variable a ?

# %%
print(type(a))
# Out:
# <class 'float'>

# %% [markdown]
# In Python the type of a variable is not definitive and can be changed. For example, we will change the type of the variable `a` by **casting** it to int. The consequence will be that we will truncate the decimals.

# %%
print(int(12.9))
print(int(a))
# Out:
# 12
# 36

# %% [markdown]
# What would bein my a variable now ?

# %%
a
# Out:
# 36.57142857142857

# %% [markdown]
# No assignment was made! The variable `a` must be overwritten by itself transformed into int.

# %%
a = int(a)
print(a)
# Out:
# 36

# %% [markdown]
# # Integer and float

# %% [markdown]
# We saw them just previously. Here is a small recap :

# %%
type(3)
# Out:
# int

# %%
type(3.14)
# Out:
# float

# %% [markdown]
# One way to use them, is a simple calculator.

# %%
3 + 4
# Out:
# 7

# %%
12 / (3 + 5)
# Out:
# 1.5

# %%
16 + 12 * (12 / (3 + 4))
# Out:
# 36.57142857142857

# %% [markdown]
# As seen previously, you can also do that with variables :

# %%
a = 3 + 4
b = 12 / a
c = 16 + 12 * b

c
# Out:
# 36.57142857142857

# %% [markdown]
# Some functions exist in Python also.

# %%
abs(-6)
# Out:
# 6

# %% [markdown]
# ### String

# %% [markdown]
# A string can contain any character and not only our alphabet (all ascii codes are accepted)

# %%
s = "hello world 2023!" # we added spaces, numbers and special characters
print(type(s))
print(s)
# Out:
# <class 'str'>
# hello world 2023!

# %% [markdown]
# Two strings can be concatenated using the `+` operation

# %%
s = "Hello world" + " 2023" + "!"
s
# Out:
# 'Hello world 2023!'

# %% [markdown]
# Not very practical when you want to insert it in a specific place! There are several ways to do this, but the most common is to use f-string! Note that the character `f` at the beginning is not a typo but indicates to Python that we are using f-string.

# %%
year = 2020
s = f"hello world {year}!"
s
# Out:
# 'hello world 2020!'

# %% [markdown]
# Python also come with some useful methods to be applied on variables containing string. Here are some of them :

# %%
word = "hello"

# %%
word.capitalize()
# Out:
# 'Hello'

# %%
word.upper() # you also have lower
# Out:
# 'HELLO'

# %% [markdown]
# ## Data structures

# %% [markdown]
# For now, we only have the so-called primary types, but what if we want to store multiple values?
#
# --> Fortunately, there are data structures :)

# %% [markdown]
# ### List

# %% [markdown]
# You can identify a list object thanks to the [ ] (square bracket), one at the begining of the list, the other one at the end.

# %%
list_example = [1, 3, 5]
list_example
# Out:
# [1, 3, 5]

# %% [markdown]
# A list contains a sequence of values, in an ordered way, you **don't need** to:
# - define the size of the list in advance
# - have the same type for all values in the list

# %%
list_example = [1, "Hello", 3.4]
list_example
# Out:
# [1, 'Hello', 3.4]

# %% [markdown]
# Type of variable `l` is now a **list**

# %%
type(list_example)
# Out:
# list

# %% [markdown]
# #### Accessing a value

# %% [markdown]
# To access a value, we use the position (index) of the item in the list. **Note that in Python, we start counting from 0 !**

# %%
print(list_example[0]) # first element
print(list_example[2]) # third element
# Out:
# 1
# 3.4

# %% [markdown]
# Items can also be accessed from the end by using negative indexes.

# %%
print(list_example[-1]) # last element
print(list_example[-2]) # second to last item
# Out:
# 3.4
# Hello

# %% [markdown]
# #### Accessing multiple values (slicing)

# %% [markdown]
# A sub-list of consecutive values can be accessed using slicing operation, i.e. by specifying the index of the first item to be retrieved and the index of the last item to be retrieved.

# %%
print(list_example[0:2]) # items with indexes 0 and 1
print(list_example[:2]) # two first
# Out:
# [1, 'Hello']
# [1, 'Hello']

# %%
print(list_example[-2:]) # two last
# Out:
# ['Hello', 3.4]

# %% [markdown]
# #### Modify a value

# %% [markdown]
# To change a value, we simply treat each item in the list as a variable. If we want to change the first value in the list l by 18, we would do:

# %%
list_example[0] = 18 # reminder : index 0 for the first element
list_example
# Out:
# [18, 'Hello', 3.4]

# %% [markdown]
# Look, the result has changed!

# %% [markdown]
# #### Add a value

# %% [markdown]
# To add a value to the list, several functions can be used:

# %%
# add value 89 in index 1
list_example.insert(1, 89) # the insert function accepts two parameters in brackets, the index and the value to be added
print(list_example)
# Out:
# [18, 89, 'Hello', 3.4]

# %%
list_example.append(9) # the append function is a special case of insert function, because it adds to the end the value
print(list_example)
# Out:
# [18, 89, 'Hello', 3.4, 9]

# %% [markdown]
# #### Delete a value

# %% [markdown]
# To delete a value by index:

# %%
list_example.pop(2)
print(list_example)
# Out:
# [18, 89, 3.4, 9]

# %% [markdown]
# #### Nested list

# %% [markdown]
# There is nothing to prevent you from adding to a list, a new list.

# %%
print(list_example)

list_example_2 = [-2, -3, -0.123]
list_example.append(list_example_2)
print(list_example)
# Out:
# [18, 89, 3.4, 9]
# [18, 89, 3.4, 9, [-2, -3, -0.123]]

# %% [markdown]
# #### Other useful functions

# %% [markdown]
# To calculate the length of a list, use the `len()` function in Python:

# %%
len(list_example)
# Out:
# 5

# %% [markdown]
# ### Dict

# %% [markdown]
# You can identify a dict object thanks to the { } (curly bracket), one at the begining of the list, the other one at the end.

# %%
dict_example = {"first_name": "Paul",
     "last_name": "Mochkovitch"}
dict_example
# Out:
# {'first_name': 'Paul', 'last_name': 'Mochkovitch'}

# %% [markdown]
# A dictionary, unlike a list, has no order. It is made up of keys / values.
#
# The keys of a dictionary are **unique** and the values can be of any type (including data structures)

# %% [markdown]
# The variable `l` defined previously is of type dict

# %%
type(dict_example)
# Out:
# dict

# %% [markdown]
# #### Access a value

# %% [markdown]
# To access an element of a dictionary, it is via the name of its key and not the index number because there is none! You can imagine that all the keys are in the first position. It is as fast to access one key as another.
#
# For example, if we want to access the value of the `first_name` key, we would write:

# %%
dict_example["first_name"] # look we use brackets [] to access a key's value
# Out:
# 'Paul'

# %% [markdown]
# #### Modify a value

# %% [markdown]
# To modify a value, you just have to consider the key as a variable. If we want to modify the value of the key `first_name` by Victor, we will write:

# %%
dict_example["first_name"] = "Victor"
dict_example
# Out:
# {'first_name': 'Victor', 'last_name': 'Mochkovitch'}

# %% [markdown]
# #### Add a key

# %% [markdown]
# To add a new key, it is enough to proceed as if one wanted to change its value. Since the key does not exist, it will create it with the assigned value.

# %%
dict_example["age"] = 30
dict_example
# Out:
# {'first_name': 'Victor', 'last_name': 'Mochkovitch', 'age': 30}

# %% [markdown]
# #### Delete a key

# %% [markdown]
# To delete a key, we use the same `pop` function as for lists.

# %%
dict_example.pop("age")
dict_example
# Out:
# {'first_name': 'Victor', 'last_name': 'Mochkovitch'}

# %% [markdown]
# #### Nested dictionnaries

# %% [markdown]
# In the same way that there is a list of list, a dictionary can have a key value that is also a dictionary. It is even very common.

# %%
dict_example["measures"] = {"height(cm)": 189, "weight": 100}
dict_example
# Out:
# {'first_name': 'Victor',
#  'last_name': 'Mochkovitch',
#  'measures': {'height(cm)': 189, 'weight': 100}}

# %% [markdown]
# How to access the "weight" value?

# %%
dict_example["measures"]["weight"]
# Out:
# 100

# %% [markdown]
# #### Other functions

# %% [markdown]
# To list all the keys in a dictionary, you can use the `.keys()` function

# %%
dict_example.keys()
# Out:
# dict_keys(['first_name', 'last_name', 'measures'])

# %% [markdown]
# To count the number of keys in a dictionary, simply use the same `len` function

# %%
len(dict_example)
# Out:
# 3

# %% [markdown]
# You can also have lists in dictionnaries and vice versa. But don't worry, we will see that in recap, nothing complicated here 😉

# %% [markdown]
# ## Conditions & operators

# %% [markdown]
# ### Comparison operators

# %% [markdown]
# - ">": for strictly superior
# - ">=" : for greater than or equal to
# - "<" : for inferior strict
# - "<=" : for less than or equal to
# - "==" : to test for equality
# - "!=" : to test the difference
# - "in": to test if an element is in a list or if an element is a key in a dictionary
# - "not in": the opposite of in

# %%
a = 3
b = 5
print(a == b)
# Out:
# False

# %%
print(int(a >= b))
print(int(a == a))
# Out:
# 0
# 1

# %% [markdown]
# ## Conditions

# %% [markdown]
# In computer science, we need to distinguish cases, so we use the `if` statement:

# %%
a = 3
b = 5

if a < b:
    print("a is strictly less than b")
# Out:
# a is strictly less than b

# %% [markdown]
# **Note**: all statements that are below and offset by a tab will be executed if the condition is true. **The offset is fundamental!**

# %% [markdown]
# With an additionnal `else` clause:

# %%
a = 3
b = 5

if a < b:
    print("a is strictly less than b")
else:
    print("a is greater or equal than b")
# Out:
# a is strictly less than b

# %% [markdown]
# For more complicated condition tests, one may want to introduce if-not, `elif`:

# %%
a = 3
b = 3
if a < b:
    print("a is strictly less than b")
elif a == b:
    print("a and b are equals")
else:
    print("a is strictly greater than b")
# Out:
# a and b are equals

# %% [markdown]
# The conditions can also be combined to create a more complicated criterion, in which case parentheses are essential. The possible operators are `&` for and `|` for or.

# %%
list_example = [1, 7, 9, 2]

if (list_example[0] < 3) & (list_example[3] < 5):
    print("Won !")
# Out:
# Won !

# %% [markdown]
# ## Loops

# %% [markdown]
# To avoid repeating instructions, it is necessary to use loops

# %%
list_example = [1, 7, 9, 2]

print(list_example[0])
print(list_example[1])
print(list_example[2])
print(list_example[3])
# Out:
# 1
# 7
# 9
# 2

# %%
for number in list_example:
    print(number)
# Out:
# 1
# 7
# 9
# 2

# %% [markdown]
# `number` is here a variable that could have been called anything, it will scan all the values that are to the right of the `in` operator, in this case [1, 7, 9, 2].
#
# There are therefore 4 values taken by the variable `number`:
# - number=1 for the first execution of the lines below
# - number=7 for the second execution of the lines below
# - number=9 for the third ...
# - number=2 for the fourth ...
#
# Below the for, we put the insctructions we want!

# %% [markdown]
# To iterate on the keys of a dictionary we proceed in the same way:

# %%
dict_example = {"cat": "gray", "dog": "black"}

for key in dict_example:
    print(key)
# Out:
# cat
# dog

# %% [markdown]
# ## Functions

# %% [markdown]
# To reproduce a series of instructions easily, functions are useful. A function is given a name and can take parameters as inputs and use them in its instructions.

# %% [markdown]
# For example, let's write a function that simply displays "Hello".

# %%
def print_hello_world():
    print("Hello")

# %%
print_hello_world()
# Out:
# Hello

# %% [markdown]
# def : states that you are starting a function
#
# Don't forget :
#
# *   the brackets after the name
# *   the : after the brackets
# *   the indentation at each lines of your functions

# %% [markdown]
# With a parameter:

# %%
def print_hello_world(first_name):
    print(f"Hello {first_name}")

# %%
print_hello_world("Paul")
# Out:
# Hello Paul

# %% [markdown]
# Here the `first_name` parameter is mandatory but you may want to make it optional by adding a default value.

# %%
def print_hello_world(first_name="world"):
    print(f"Hello {first_name}")

# %%
print_hello_world()
# Out:
# Hello world

# %%
print_hello_world("Paul")
# Out:
# Hello Paul

# %% [markdown]
# Here the function only display a result (use of print). What if I want my function to return a result that I can use after ?
# -> I will use a return statement !

# %%
def number_multiplication(a, b):
  return a*b

# %%
a = number_multiplication(2, 3)

# %%
a
# Out:
# 6

# %% [markdown]
# # Let's code !
